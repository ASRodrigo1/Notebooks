# %%
import warnings
warnings.simplefilter('ignore')
import tensorflow as tf
print("Is GPU available?", tf.test.is_gpu_available())
print("TF version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
# Out:
# Is GPU available? True
# TF version: 1.15.0
# Keras version: 2.2.4-tf

# %%
import gym
import numpy as np
import random
import matplotlib.pyplot as plt
from collections import deque
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %%
class Agent():
    def __init__(self, input_shape, n_actions, mem_size, eps, eps_min, eps_dec, gamma, q_eval_name, q_next_name, 
                 replace_freq, lr=0.0001):
        self.Q_eval = self._build_NN(input_shape, n_actions, lr)
        self.Q_next = self._build_NN(input_shape, n_actions, lr)
        #self.Q_eval = load_model('Q_eval.h5')
        #self.Q_next = load_model('Q_next.h5')
        self.memory = deque(maxlen=mem_size)
        self.eps = eps
        self.eps_min = eps_min
        self.eps_dec = eps_dec
        self.gamma = gamma
        self.replace = replace_freq
        self.action_space = [i for i in range(n_actions)]
        self.steps = 0
        self.input_shape = input_shape
        self.q_eval_name = q_eval_name
        self.q_next_name = q_next_name
    
    def _build_NN(self, input_shape, n_actions, lr):
        
        model = Sequential()
        
        model.add(Dense(32, input_shape=(*input_shape,), activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(n_actions, activation='linear'))
        
        model.compile(optimizer=Adam(lr=lr), loss='mse')
        
        model.summary()
        
        return model
    
    def store(self, state, action, reward, n_state, done):
        pack = [np.expand_dims(state, axis=0), action, reward, np.expand_dims(n_state, axis=0), done]
        self.memory.append(pack)
    
    def take_data(self, batch_size):
        pack = random.sample(self.memory, batch_size)
        states = []
        actions = []
        rewards = []
        n_states = []
        dones = []
        for i in range(batch_size):
            states.append(pack[i][0])
            actions.append(pack[i][1])
            rewards.append(pack[i][2])
            n_states.append(pack[i][3])
            dones.append(pack[i][4])
        return states, actions, rewards, n_states, dones
    
    def choose_action(self, state):
        if np.random.random() > self.eps:
            return np.argmax(self.Q_next.predict(state))
        else:
            return np.random.choice(self.action_space)
    
    def decay_eps(self): 
        self.eps = self.eps - self.eps_dec if self.eps > self.eps_min else self.eps_min
    
    def replace_weights(self):
        if not (self.steps % self.replace):
            self.Q_next.set_weights(self.Q_eval.get_weights())
            print('Atualizado')
    
    def upgrade(self, batch_size=64):
        if len(self.memory) >= 4*batch_size:
            states, actions, rewards, n_states, dones = self.take_data(batch_size)
            
            ### DDQN
            act = [np.argmax(self.Q_eval.predict(n_states[i])) for i in range(batch_size)]
            
            q_next = [self.Q_next.predict(n_states[i])[0][act[i]] for i in range(batch_size)]
            
            y = [self.Q_eval.predict(states[i])[0] for i in range(batch_size)]
            
            for i in range(batch_size):
                y[i][act[i]] = rewards[i] + self.gamma*q_next[i]*dones[i]
            ###
            
            states = np.reshape(states, (batch_size, *self.input_shape))
            
            _ = self.Q_eval.fit(np.array(states), np.array(y), epochs=1, verbose=0, batch_size=batch_size)
            
            self.decay_eps()
            self.replace_weights()

    def save(self):
        self.Q_eval.save(self.q_eval_name)
        self.Q_next.save(self.q_next_name)

# %%
env = gym.make('CartPole-v1')
n_games = 1000
agent = Agent(input_shape=env.observation_space.shape, n_actions=env.action_space.n, mem_size=10000, eps=1.0, 
              eps_min=0.001, eps_dec=0.001, gamma=1.0, q_eval_name='Q_eval.h5', q_next_name='Q_next.h5', 
              replace_freq=250)
best_score = -200
scores = []
means = []
eps = []
for i in range(n_games):
    done = False
    state = env.reset()
    score = 0
    while not done:
        action = agent.choose_action(np.expand_dims(state, axis=0))
        n_state, reward, done, _ = env.step(action)
        score += reward
        agent.steps += 1
        agent.store(state, action, reward, n_state, (int(done)))
        agent.upgrade()
        state = n_state
    scores.append(score)
    mean = np.mean(scores[-20:])
    means.append(mean)
    eps.append(agent.eps)
    if mean > best_score:
        agent.save()
        best_score = mean
    print('episode: ', i+1, '   score: ', score, '   eps:  %.3f' %agent.eps)
    if np.mean(scores[-100:]) > 195:
        print("Environment Solved!")
        agent.save()
        break
env.close()
# Out:
# WARNING:tensorflow:From C:\Users\Rodrigo\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                160
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 2,402
# Trainable params: 2,402
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                160
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 2,402
# Trainable params: 2,402
# Non-trainable params: 0
# _________________________________________________________________
# episode:  1    score:  18.0    eps:  1.000
# episode:  2    score:  51.0    eps:  1.000
# episode:  3    score:  24.0    eps:  1.000
# episode:  4    score:  22.0    eps:  1.000
# episode:  5    score:  11.0    eps:  1.000
# episode:  6    score:  26.0    eps:  1.000
# episode:  7    score:  10.0    eps:  1.000
# episode:  8    score:  31.0    eps:  1.000
# episode:  9    score:  17.0    eps:  1.000
# episode:  10    score:  17.0    eps:  1.000
# episode:  11    score:  16.0    eps:  1.000
# episode:  12    score:  19.0    eps:  0.993
# episode:  13    score:  45.0    eps:  0.948
# episode:  14    score:  32.0    eps:  0.916
# episode:  15    score:  11.0    eps:  0.905
# episode:  16    score:  17.0    eps:  0.888
# episode:  17    score:  13.0    eps:  0.875
# episode:  18    score:  11.0    eps:  0.864
# episode:  19    score:  32.0    eps:  0.832
# episode:  20    score:  14.0    eps:  0.818
# episode:  21    score:  17.0    eps:  0.801
# episode:  22    score:  13.0    eps:  0.788
# episode:  23    score:  15.0    eps:  0.773
# episode:  24    score:  17.0    eps:  0.756
# Atualizado
# episode:  25    score:  12.0    eps:  0.744
# episode:  26    score:  17.0    eps:  0.727
# episode:  27    score:  12.0    eps:  0.715
# episode:  28    score:  16.0    eps:  0.699
# episode:  29    score:  10.0    eps:  0.689
# episode:  30    score:  19.0    eps:  0.670
# episode:  31    score:  14.0    eps:  0.656
# episode:  32    score:  15.0    eps:  0.641
# episode:  33    score:  12.0    eps:  0.629
# episode:  34    score:  12.0    eps:  0.617
# episode:  35    score:  8.0    eps:  0.609
# episode:  36    score:  9.0    eps:  0.600
# episode:  37    score:  17.0    eps:  0.583
# episode:  38    score:  10.0    eps:  0.573
# episode:  39    score:  11.0    eps:  0.562
# episode:  40    score:  24.0    eps:  0.538
# Atualizado
# episode:  41    score:  34.0    eps:  0.504
# episode:  42    score:  12.0    eps:  0.492
# episode:  43    score:  12.0    eps:  0.480
# episode:  44    score:  14.0    eps:  0.466
# episode:  45    score:  9.0    eps:  0.457
# episode:  46    score:  11.0    eps:  0.446
# episode:  47    score:  10.0    eps:  0.436
# episode:  48    score:  12.0    eps:  0.424
# episode:  49    score:  12.0    eps:  0.412
# episode:  50    score:  9.0    eps:  0.403
# episode:  51    score:  8.0    eps:  0.395
# episode:  52    score:  9.0    eps:  0.386
# episode:  53    score:  11.0    eps:  0.375
# episode:  54    score:  11.0    eps:  0.364
# episode:  55    score:  10.0    eps:  0.354
# episode:  56    score:  10.0    eps:  0.344
# episode:  57    score:  12.0    eps:  0.332
# episode:  58    score:  8.0    eps:  0.324
# episode:  59    score:  12.0    eps:  0.312
# episode:  60    score:  11.0    eps:  0.301
# episode:  61    score:  13.0    eps:  0.288
# episode:  62    score:  8.0    eps:  0.280
# episode:  63    score:  12.0    eps:  0.268
# episode:  64    score:  12.0    eps:  0.256
# Atualizado
# episode:  65    score:  11.0    eps:  0.245
# episode:  66    score:  9.0    eps:  0.236
# episode:  67    score:  10.0    eps:  0.226
# episode:  68    score:  10.0    eps:  0.216
# episode:  69    score:  9.0    eps:  0.207
# episode:  70    score:  10.0    eps:  0.197
# episode:  71    score:  11.0    eps:  0.186
# episode:  72    score:  9.0    eps:  0.177
# episode:  73    score:  11.0    eps:  0.166
# episode:  74    score:  12.0    eps:  0.154
# episode:  75    score:  12.0    eps:  0.142
# episode:  76    score:  12.0    eps:  0.130
# episode:  77    score:  13.0    eps:  0.117
# episode:  78    score:  10.0    eps:  0.107
# episode:  79    score:  9.0    eps:  0.098
# episode:  80    score:  9.0    eps:  0.089
# episode:  81    score:  10.0    eps:  0.079
# episode:  82    score:  10.0    eps:  0.069
# episode:  83    score:  11.0    eps:  0.058
# episode:  84    score:  11.0    eps:  0.047
# episode:  85    score:  9.0    eps:  0.038
# episode:  86    score:  8.0    eps:  0.030
# episode:  87    score:  10.0    eps:  0.020
# episode:  88    score:  11.0    eps:  0.009
# Atualizado
# episode:  89    score:  9.0    eps:  0.001
# episode:  90    score:  9.0    eps:  0.001
# episode:  91    score:  8.0    eps:  0.001
# episode:  92    score:  9.0    eps:  0.001
# episode:  93    score:  10.0    eps:  0.001
# episode:  94    score:  9.0    eps:  0.001
# episode:  95    score:  10.0    eps:  0.001
# episode:  96    score:  10.0    eps:  0.001
# episode:  97    score:  8.0    eps:  0.001
# episode:  98    score:  8.0    eps:  0.001
# episode:  99    score:  9.0    eps:  0.001
# episode:  100    score:  9.0    eps:  0.001
# episode:  101    score:  9.0    eps:  0.001
# episode:  102    score:  10.0    eps:  0.001
# episode:  103    score:  10.0    eps:  0.001
# episode:  104    score:  10.0    eps:  0.001
# episode:  105    score:  10.0    eps:  0.001
# episode:  106    score:  8.0    eps:  0.001
# episode:  107    score:  10.0    eps:  0.001
# episode:  108    score:  10.0    eps:  0.001
# episode:  109    score:  9.0    eps:  0.001
# episode:  110    score:  11.0    eps:  0.001
# episode:  111    score:  10.0    eps:  0.001
# episode:  112    score:  10.0    eps:  0.001
# episode:  113    score:  10.0    eps:  0.001
# episode:  114    score:  9.0    eps:  0.001
# Atualizado
# episode:  115    score:  10.0    eps:  0.001
# episode:  116    score:  9.0    eps:  0.001
# episode:  117    score:  10.0    eps:  0.001
# episode:  118    score:  11.0    eps:  0.001
# episode:  119    score:  9.0    eps:  0.001
# episode:  120    score:  9.0    eps:  0.001
# episode:  121    score:  9.0    eps:  0.001
# episode:  122    score:  9.0    eps:  0.001
# episode:  123    score:  9.0    eps:  0.001
# episode:  124    score:  10.0    eps:  0.001
# episode:  125    score:  10.0    eps:  0.001
# episode:  126    score:  9.0    eps:  0.001
# episode:  127    score:  10.0    eps:  0.001
# episode:  128    score:  10.0    eps:  0.001
# episode:  129    score:  10.0    eps:  0.001
# episode:  130    score:  8.0    eps:  0.001
# episode:  131    score:  9.0    eps:  0.001
# episode:  132    score:  9.0    eps:  0.001
# episode:  133    score:  9.0    eps:  0.001
# episode:  134    score:  8.0    eps:  0.001
# episode:  135    score:  9.0    eps:  0.001
# episode:  136    score:  10.0    eps:  0.001
# episode:  137    score:  10.0    eps:  0.001
# episode:  138    score:  10.0    eps:  0.001
# episode:  139    score:  10.0    eps:  0.001
# episode:  140    score:  10.0    eps:  0.001
# episode:  141    score:  10.0    eps:  0.001
# Atualizado
# episode:  142    score:  9.0    eps:  0.001
# episode:  143    score:  9.0    eps:  0.001
# episode:  144    score:  8.0    eps:  0.001
# episode:  145    score:  9.0    eps:  0.001
# episode:  146    score:  9.0    eps:  0.001
# episode:  147    score:  9.0    eps:  0.001
# episode:  148    score:  9.0    eps:  0.001
# episode:  149    score:  10.0    eps:  0.001
# episode:  150    score:  10.0    eps:  0.001
# episode:  151    score:  10.0    eps:  0.001
# episode:  152    score:  10.0    eps:  0.001
# episode:  153    score:  10.0    eps:  0.001
# episode:  154    score:  10.0    eps:  0.001
# episode:  155    score:  10.0    eps:  0.001
# episode:  156    score:  8.0    eps:  0.001
# episode:  157    score:  9.0    eps:  0.001
# episode:  158    score:  8.0    eps:  0.001
# episode:  159    score:  9.0    eps:  0.001
# episode:  160    score:  10.0    eps:  0.001
# episode:  161    score:  10.0    eps:  0.001
# episode:  162    score:  9.0    eps:  0.001
# episode:  163    score:  11.0    eps:  0.001
# episode:  164    score:  9.0    eps:  0.001
# episode:  165    score:  10.0    eps:  0.001
# episode:  166    score:  9.0    eps:  0.001
# episode:  167    score:  10.0    eps:  0.001
# Atualizado
# episode:  168    score:  10.0    eps:  0.001
# episode:  169    score:  8.0    eps:  0.001
# episode:  170    score:  9.0    eps:  0.001
# episode:  171    score:  10.0    eps:  0.001
# episode:  172    score:  10.0    eps:  0.001
# episode:  173    score:  8.0    eps:  0.001
# episode:  174    score:  9.0    eps:  0.001
# episode:  175    score:  10.0    eps:  0.001
# episode:  176    score:  9.0    eps:  0.001
# episode:  177    score:  10.0    eps:  0.001
# episode:  178    score:  9.0    eps:  0.001
# episode:  179    score:  9.0    eps:  0.001
# episode:  180    score:  9.0    eps:  0.001
# episode:  181    score:  9.0    eps:  0.001
# episode:  182    score:  8.0    eps:  0.001
# episode:  183    score:  10.0    eps:  0.001
# episode:  184    score:  9.0    eps:  0.001
# episode:  185    score:  10.0    eps:  0.001
# episode:  186    score:  10.0    eps:  0.001
# episode:  187    score:  9.0    eps:  0.001
# episode:  188    score:  10.0    eps:  0.001
# episode:  189    score:  8.0    eps:  0.001
# episode:  190    score:  10.0    eps:  0.001
# episode:  191    score:  10.0    eps:  0.001
# episode:  192    score:  10.0    eps:  0.001
# episode:  193    score:  8.0    eps:  0.001
# episode:  194    score:  10.0    eps:  0.001
# Atualizado
# episode:  195    score:  10.0    eps:  0.001
# episode:  196    score:  9.0    eps:  0.001
# episode:  197    score:  10.0    eps:  0.001
# episode:  198    score:  11.0    eps:  0.001
# episode:  199    score:  9.0    eps:  0.001
# episode:  200    score:  10.0    eps:  0.001
# episode:  201    score:  8.0    eps:  0.001
# episode:  202    score:  9.0    eps:  0.001
# episode:  203    score:  9.0    eps:  0.001
# episode:  204    score:  10.0    eps:  0.001
# episode:  205    score:  9.0    eps:  0.001
# episode:  206    score:  9.0    eps:  0.001
# episode:  207    score:  9.0    eps:  0.001
# episode:  208    score:  9.0    eps:  0.001
# episode:  209    score:  9.0    eps:  0.001
# episode:  210    score:  10.0    eps:  0.001
# episode:  211    score:  9.0    eps:  0.001
# episode:  212    score:  10.0    eps:  0.001
# episode:  213    score:  10.0    eps:  0.001
# episode:  214    score:  8.0    eps:  0.001
# episode:  215    score:  9.0    eps:  0.001
# episode:  216    score:  10.0    eps:  0.001
# episode:  217    score:  10.0    eps:  0.001
# episode:  218    score:  8.0    eps:  0.001
# episode:  219    score:  10.0    eps:  0.001
# episode:  220    score:  10.0    eps:  0.001
# episode:  221    score:  9.0    eps:  0.001
# Atualizado
# episode:  222    score:  8.0    eps:  0.001
# episode:  223    score:  10.0    eps:  0.001
# episode:  224    score:  9.0    eps:  0.001
# episode:  225    score:  9.0    eps:  0.001
# episode:  226    score:  10.0    eps:  0.001
# episode:  227    score:  10.0    eps:  0.001
# episode:  228    score:  9.0    eps:  0.001
# episode:  229    score:  10.0    eps:  0.001
# episode:  230    score:  9.0    eps:  0.001
# episode:  231    score:  9.0    eps:  0.001
# episode:  232    score:  10.0    eps:  0.001
# episode:  233    score:  9.0    eps:  0.001
# episode:  234    score:  10.0    eps:  0.001
# episode:  235    score:  10.0    eps:  0.001
# episode:  236    score:  10.0    eps:  0.001
# episode:  237    score:  10.0    eps:  0.001
# episode:  238    score:  9.0    eps:  0.001
# episode:  239    score:  10.0    eps:  0.001
# episode:  240    score:  9.0    eps:  0.001
# episode:  241    score:  9.0    eps:  0.001
# episode:  242    score:  10.0    eps:  0.001
# episode:  243    score:  10.0    eps:  0.001
# episode:  244    score:  9.0    eps:  0.001
# episode:  245    score:  9.0    eps:  0.001
# episode:  246    score:  9.0    eps:  0.001
# episode:  247    score:  9.0    eps:  0.001
# episode:  248    score:  10.0    eps:  0.001
# Atualizado
# episode:  249    score:  9.0    eps:  0.001
# episode:  250    score:  10.0    eps:  0.001
# episode:  251    score:  10.0    eps:  0.001
# episode:  252    score:  11.0    eps:  0.001
# episode:  253    score:  9.0    eps:  0.001
# episode:  254    score:  8.0    eps:  0.001
# episode:  255    score:  10.0    eps:  0.001
# episode:  256    score:  10.0    eps:  0.001
# episode:  257    score:  9.0    eps:  0.001
# episode:  258    score:  9.0    eps:  0.001
# episode:  259    score:  8.0    eps:  0.001
# episode:  260    score:  9.0    eps:  0.001
# episode:  261    score:  8.0    eps:  0.001
# episode:  262    score:  8.0    eps:  0.001
# episode:  263    score:  10.0    eps:  0.001
# episode:  264    score:  10.0    eps:  0.001
# episode:  265    score:  8.0    eps:  0.001
# episode:  266    score:  9.0    eps:  0.001
# episode:  267    score:  10.0    eps:  0.001
# episode:  268    score:  8.0    eps:  0.001
# episode:  269    score:  10.0    eps:  0.001
# episode:  270    score:  10.0    eps:  0.001
# episode:  271    score:  8.0    eps:  0.001
# episode:  272    score:  9.0    eps:  0.001
# episode:  273    score:  10.0    eps:  0.001
# episode:  274    score:  9.0    eps:  0.001
# episode:  275    score:  11.0    eps:  0.001
# Atualizado
# episode:  276    score:  9.0    eps:  0.001
# episode:  277    score:  9.0    eps:  0.001
# episode:  278    score:  9.0    eps:  0.001
# episode:  279    score:  9.0    eps:  0.001
# episode:  280    score:  10.0    eps:  0.001
# episode:  281    score:  8.0    eps:  0.001
# episode:  282    score:  10.0    eps:  0.001
# episode:  283    score:  10.0    eps:  0.001
# episode:  284    score:  10.0    eps:  0.001
# episode:  285    score:  9.0    eps:  0.001
# episode:  286    score:  9.0    eps:  0.001
# episode:  287    score:  10.0    eps:  0.001
# episode:  288    score:  10.0    eps:  0.001
# episode:  289    score:  9.0    eps:  0.001
# episode:  290    score:  10.0    eps:  0.001
# episode:  291    score:  9.0    eps:  0.001
# episode:  292    score:  9.0    eps:  0.001
# episode:  293    score:  9.0    eps:  0.001
# episode:  294    score:  9.0    eps:  0.001
# episode:  295    score:  8.0    eps:  0.001
# episode:  296    score:  9.0    eps:  0.001
# episode:  297    score:  10.0    eps:  0.001
# episode:  298    score:  10.0    eps:  0.001
# episode:  299    score:  9.0    eps:  0.001
# episode:  300    score:  9.0    eps:  0.001
# episode:  301    score:  10.0    eps:  0.001
# Atualizado
# episode:  302    score:  10.0    eps:  0.001
# episode:  303    score:  10.0    eps:  0.001
# episode:  304    score:  9.0    eps:  0.001
# episode:  305    score:  10.0    eps:  0.001
# episode:  306    score:  10.0    eps:  0.001
# episode:  307    score:  8.0    eps:  0.001
# episode:  308    score:  9.0    eps:  0.001
# episode:  309    score:  9.0    eps:  0.001
# episode:  310    score:  8.0    eps:  0.001
# episode:  311    score:  10.0    eps:  0.001
# episode:  312    score:  10.0    eps:  0.001
# episode:  313    score:  9.0    eps:  0.001
# episode:  314    score:  9.0    eps:  0.001
# episode:  315    score:  9.0    eps:  0.001
# episode:  316    score:  9.0    eps:  0.001
# episode:  317    score:  10.0    eps:  0.001
# episode:  318    score:  10.0    eps:  0.001
# episode:  319    score:  10.0    eps:  0.001
# episode:  320    score:  10.0    eps:  0.001
# episode:  321    score:  9.0    eps:  0.001
# episode:  322    score:  9.0    eps:  0.001
# episode:  323    score:  10.0    eps:  0.001
# episode:  324    score:  9.0    eps:  0.001
# episode:  325    score:  9.0    eps:  0.001
# episode:  326    score:  10.0    eps:  0.001
# episode:  327    score:  10.0    eps:  0.001
# episode:  328    score:  8.0    eps:  0.001
# Atualizado
# episode:  329    score:  10.0    eps:  0.001
# episode:  330    score:  9.0    eps:  0.001
# episode:  331    score:  9.0    eps:  0.001
# episode:  332    score:  10.0    eps:  0.001
# episode:  333    score:  8.0    eps:  0.001
# episode:  334    score:  9.0    eps:  0.001
# episode:  335    score:  10.0    eps:  0.001
# episode:  336    score:  9.0    eps:  0.001
# episode:  337    score:  10.0    eps:  0.001
# episode:  338    score:  10.0    eps:  0.001
# episode:  339    score:  9.0    eps:  0.001
# episode:  340    score:  8.0    eps:  0.001
# episode:  341    score:  10.0    eps:  0.001
# episode:  342    score:  10.0    eps:  0.001
# episode:  343    score:  10.0    eps:  0.001
# episode:  344    score:  9.0    eps:  0.001
# episode:  345    score:  8.0    eps:  0.001
# episode:  346    score:  10.0    eps:  0.001
# episode:  347    score:  8.0    eps:  0.001
# episode:  348    score:  9.0    eps:  0.001
# episode:  349    score:  9.0    eps:  0.001
# episode:  350    score:  10.0    eps:  0.001
# episode:  351    score:  10.0    eps:  0.001
# episode:  352    score:  11.0    eps:  0.001
# episode:  353    score:  10.0    eps:  0.001
# episode:  354    score:  9.0    eps:  0.001
# episode:  355    score:  9.0    eps:  0.001
# Atualizado
# episode:  356    score:  9.0    eps:  0.001

# %%
plt.plot(scores)
plt.grid()
plt.show()

# %%
plt.plot(means)
plt.grid()
plt.show()

# %%
plt.plot(eps)
plt.grid()
plt.show()

# %%
Q = load_model('Q_next.h5')
env = gym.make('CartPole-v1')
for i in range(20):
    done = False
    state = env.reset()
    while not done:
        env.render()
        action = np.argmax(Q.predict(np.expand_dims(state, axis=0))[0])
        n_state, reward, done, _ = env.step(action)
        state = n_state
env.close()
