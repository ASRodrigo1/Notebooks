# %%
import warnings
warnings.simplefilter('ignore')
import tensorflow as tf

# %%
print("Is GPU available?", tf.test.is_gpu_available())
print("TF version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
# Out:
# WARNING:tensorflow:From <ipython-input-2-ef76775f4c1a>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Is GPU available? True
# TF version: 2.3.1
# Keras version: 2.4.0

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MSE

from collections import deque
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
class Critic(tf.keras.Model):
    def __init__(self):
        super(Critic, self).__init__()
        self.f1 = tf.keras.layers.Dense(512, activation='relu')
        self.f2 = tf.keras.layers.Dense(512, activation='relu')
        self.v =  tf.keras.layers.Dense(1, activation=None)

    def call(self, state, action, goal):
        x = self.f1(tf.concat([state, action, goal], axis=1))
        x = self.f2(x)
        x = self.v(x)
        return x


class Actor(tf.keras.Model):
    def __init__(self, no_action):
        super(Actor, self).__init__()    
        self.f1 = tf.keras.layers.Dense(512, activation='relu')
        self.f2 = tf.keras.layers.Dense(512, activation='relu')
        self.mu =  tf.keras.layers.Dense(no_action, activation='tanh')

    def call(self, state, goal):
        x = self.f1(tf.concat([state, goal], axis=1))
        x = self.f2(x)
        x = self.mu(x)  
        return x

# %%
class Agent():
    def __init__(self, n_actions, min_action, max_action):
        self.actor_main = Actor(n_actions)
        self.actor_target = Actor(n_actions)
        self.critic_main = Critic()
        self.critic_main2 = Critic()
        self.critic_target = Critic()
        self.critic_target2 = Critic()
        self.batch_size = 64
        self.n_actions = n_actions
        self.a_opt = tf.keras.optimizers.Adam(0.001)
        self.c_opt1 = tf.keras.optimizers.Adam(0.002)
        self.c_opt2 = tf.keras.optimizers.Adam(0.002)
        self.memory = deque(maxlen=100000)
        self.trainstep = 0
        self.gamma = 0.99
        self.min_action = min_action
        self.max_action = max_action
        self.actor_update_steps = 2
        self.warmup = 200
        self.actor_target.compile(optimizer=self.a_opt)
        self.critic_target.compile(optimizer=self.c_opt1)
        self.critic_target2.compile(optimizer=self.c_opt2)
        self.tau = 0.005


    def act(self, state, desired_goal, evaluate=False):
        if self.trainstep > self.warmup:
            evaluate = True
        state = tf.convert_to_tensor([state], dtype=tf.float32)
        goal = tf.convert_to_tensor([desired_goal], dtype=tf.float32)
        actions = self.actor_main(state, goal)
        if not evaluate:
            actions += tf.random.normal(shape=[self.n_actions], mean=0.0, stddev=0.1)

        actions = self.max_action * (tf.clip_by_value(actions, self.min_action, self.max_action))
        
        return actions[0]
    
    def store(self, state, action, reward, n_state, done, desired_goal):
        pack = [state, action, reward, n_state, 1 - int(done), desired_goal]
        self.memory.append(pack)
    
    def take_data(self, batch_size):
        pack = random.sample(self.memory, batch_size)
        states = []
        actions = []
        rewards = []
        n_states = []
        dones = []
        goals = []
        for i in range(batch_size):
            states.append(pack[i][0])
            actions.append(pack[i][1])
            rewards.append(pack[i][2])
            n_states.append(pack[i][3])
            dones.append(pack[i][4])
            goals.append(pack[i][5])
        return states, actions, rewards, n_states, dones, goals

    def update_target(self, tau=None):

        if tau is None:
            tau = self.tau

        weights1 = []
        targets1 = self.actor_target.weights
        for i, weight in enumerate(self.actor_main.weights):
            weights1.append(weight * tau + targets1[i]*(1-tau))
        self.actor_target.set_weights(weights1)

        weights2 = []
        targets2 = self.critic_target.weights
        for i, weight in enumerate(self.critic_main.weights):
            weights2.append(weight * tau + targets2[i]*(1-tau))
        self.critic_target.set_weights(weights2)


        weights3 = []
        targets3 = self.critic_target2.weights
        for i, weight in enumerate(self.critic_main2.weights):
            weights3.append(weight * tau + targets3[i]*(1-tau))
        self.critic_target2.set_weights(weights3)
    
    def upgrade(self):
        if len(self.memory) < 2*self.batch_size:
            return 


        states, actions, rewards, n_states, dones, goals = self.take_data(self.batch_size)

        states = tf.convert_to_tensor(states, dtype=tf.float32)
        n_states = tf.convert_to_tensor(n_states, dtype=tf.float32)
        rewards = tf.convert_to_tensor(rewards, dtype=tf.float32)
        actions = tf.convert_to_tensor(actions, dtype=tf.float32)
        goals = tf.convert_to_tensor(goals, dtype=tf.float32)

        with tf.GradientTape() as tape1, tf.GradientTape() as tape2:

            target_actions = self.actor_target(n_states, goals)
            target_actions += tf.clip_by_value(tf.random.normal(shape=[*np.shape(target_actions)], mean=0.0, stddev=0.2), -0.5, 0.5)
            target_actions = self.max_action * (tf.clip_by_value(target_actions, self.min_action, self.max_action))


            target_next_state_values = tf.squeeze(self.critic_target(n_states, target_actions, goals), 1)
            target_next_state_values2 = tf.squeeze(self.critic_target2(n_states, target_actions, goals), 1)

            critic_value = tf.squeeze(self.critic_main(states, actions, goals), 1)
            critic_value2 = tf.squeeze(self.critic_main2(states, actions, goals), 1)

            next_state_target_value = tf.math.minimum(target_next_state_values, target_next_state_values2)

            target_values = rewards + self.gamma * next_state_target_value * dones
            critic_loss1 = tf.keras.losses.MSE(target_values, critic_value)
            critic_loss2 = tf.keras.losses.MSE(target_values, critic_value2)




        grads1 = tape1.gradient(critic_loss1, self.critic_main.trainable_variables)
        grads2 = tape2.gradient(critic_loss2, self.critic_main2.trainable_variables)

        self.c_opt1.apply_gradients(zip(grads1, self.critic_main.trainable_variables))
        self.c_opt2.apply_gradients(zip(grads2, self.critic_main2.trainable_variables))


        self.trainstep +=1

        if self.trainstep % self.actor_update_steps == 0:

            with tf.GradientTape() as tape3:

                new_policy_actions = self.actor_main(states, goals)
                actor_loss = -self.critic_main(states, new_policy_actions, goals)
                actor_loss = tf.math.reduce_mean(actor_loss)

            grads3 = tape3.gradient(actor_loss, self.actor_main.trainable_variables)
            self.a_opt.apply_gradients(zip(grads3, self.actor_main.trainable_variables))

        self.update_target()

# %%
import gym
env = gym.make('FetchReach-v1')

print('Min_action:', env.action_space.low[0])
print('Max_action: ', env.action_space.high[0])
print('States: ', env.observation_space.shape)
print('Actions: ', env.action_space.shape)
# Out:
# Min_action: -1.0
# Max_action:  1.0
# States:  None
# Actions:  (4,)

# %%
### My implementation of TD3 + HER

agent = Agent(4, -1.0, 1.0)

n_episodes = 8100
scores = []
avg_scores = []

for i in range(n_episodes):
    score = 0
    done = False
    dic = env.reset()
    state, desired_goal = dic['observation'], dic['desired_goal']
    temp = []
    
    while not done:
        action = agent.act(state, desired_goal)
        dic, reward, done, info = env.step(action)
        n_state, achieved_goal = dic['observation'], dic['achieved_goal']
        
        agent.store(state, action, reward, n_state, done, desired_goal)
        temp.append([state, action, reward, n_state, done, achieved_goal, info])
        
        state = n_state
        score += reward
        agent.upgrade()
        
    if (achieved_goal != desired_goal).all():
        desired_goal = achieved_goal
        for t in range(len(temp)):
            state, action, reward, n_state, done, achieved_goal, info = temp[t]
            reward = env.compute_reward(desired_goal, achieved_goal, info)
            done = False if reward else True
            agent.store(state, action, reward, n_state, done, desired_goal)
            #print(reward, done, achieved_goal, desired_goal)
    
    scores.append(score)
    avg = np.mean(scores[-100:])
    avg_scores.append(avg)
    print(f'Episode {i}  Score {score}  AVG {avg}')

env.close()
# Out:
# Episode 0  Score -50.0  AVG -50.0
# Episode 1  Score -50.0  AVG -50.0
# Episode 2  Score -50.0  AVG -50.0
# Episode 3  Score -50.0  AVG -50.0
# Episode 4  Score -50.0  AVG -50.0
# Episode 5  Score -50.0  AVG -50.0
# Episode 6  Score -50.0  AVG -50.0
# Episode 7  Score -50.0  AVG -50.0
# Episode 8  Score -50.0  AVG -50.0
# Episode 9  Score -50.0  AVG -50.0
# Episode 10  Score -50.0  AVG -50.0
# Episode 11  Score -50.0  AVG -50.0
# Episode 12  Score -50.0  AVG -50.0
# Episode 13  Score -48.0  AVG -49.857142857142854
# Episode 14  Score -50.0  AVG -49.86666666666667
# Episode 15  Score -50.0  AVG -49.875
# Episode 16  Score -50.0  AVG -49.88235294117647
# Episode 17  Score -50.0  AVG -49.888888888888886
# Episode 18  Score -50.0  AVG -49.89473684210526
# Episode 19  Score -50.0  AVG -49.9
# Episode 20  Score -50.0  AVG -49.904761904761905
# Episode 21  Score -50.0  AVG -49.90909090909091
# Episode 22  Score -50.0  AVG -49.91304347826087
# Episode 23  Score -50.0  AVG -49.916666666666664
# Episode 24  Score -39.0  AVG -49.48
# Episode 25  Score -50.0  AVG -49.5
# Episode 26  Score -50.0  AVG -49.51851851851852
# Episode 27  Score -50.0  AVG -49.535714285714285
# Episode 28  Score -50.0  AVG -49.55172413793103
# Episode 29  Score -50.0  AVG -49.56666666666667
# Episode 30  Score -50.0  AVG -49.58064516129032
# Episode 31  Score -50.0  AVG -49.59375
# Episode 32  Score -50.0  AVG -49.60606060606061
# Episode 33  Score -50.0  AVG -49.61764705882353
# Episode 34  Score -50.0  AVG -49.628571428571426
# Episode 35  Score -50.0  AVG -49.638888888888886
# Episode 36  Score -50.0  AVG -49.648648648648646
# Episode 37  Score -50.0  AVG -49.6578947368421
# Episode 38  Score -50.0  AVG -49.666666666666664
# Episode 39  Score -50.0  AVG -49.675
# Episode 40  Score -50.0  AVG -49.68292682926829
# Episode 41  Score -50.0  AVG -49.69047619047619
# Episode 42  Score -43.0  AVG -49.53488372093023
# Episode 43  Score -50.0  AVG -49.54545454545455
# Episode 44  Score -50.0  AVG -49.55555555555556
# Episode 45  Score -50.0  AVG -49.56521739130435
# Episode 46  Score -50.0  AVG -49.57446808510638
# Episode 47  Score -50.0  AVG -49.583333333333336
# Episode 48  Score -50.0  AVG -49.59183673469388
# Episode 49  Score -50.0  AVG -49.6
# Episode 50  Score -50.0  AVG -49.6078431372549
# Episode 51  Score -50.0  AVG -49.61538461538461
# Episode 52  Score -50.0  AVG -49.62264150943396
# Episode 53  Score -50.0  AVG -49.629629629629626
# Episode 54  Score -50.0  AVG -49.63636363636363
# Episode 55  Score -50.0  AVG -49.642857142857146
# Episode 56  Score -50.0  AVG -49.64912280701754
# Episode 57  Score -50.0  AVG -49.6551724137931
# Episode 58  Score -50.0  AVG -49.66101694915254
# Episode 59  Score -50.0  AVG -49.666666666666664
# Episode 60  Score -50.0  AVG -49.67213114754098
# Episode 61  Score -50.0  AVG -49.67741935483871
# Episode 62  Score -50.0  AVG -49.682539682539684
# Episode 63  Score -50.0  AVG -49.6875
# Episode 64  Score -50.0  AVG -49.69230769230769
# Episode 65  Score -50.0  AVG -49.696969696969695
# Episode 66  Score -50.0  AVG -49.701492537313435
# Episode 67  Score -50.0  AVG -49.705882352941174
# Episode 68  Score -50.0  AVG -49.710144927536234
# Episode 69  Score -50.0  AVG -49.714285714285715
# Episode 70  Score -50.0  AVG -49.71830985915493
# Episode 71  Score -41.0  AVG -49.59722222222222
# Episode 72  Score -50.0  AVG -49.602739726027394
# Episode 73  Score -50.0  AVG -49.608108108108105
# Episode 74  Score -50.0  AVG -49.61333333333334
# Episode 75  Score -50.0  AVG -49.61842105263158
# Episode 76  Score -50.0  AVG -49.62337662337662
# Episode 77  Score -49.0  AVG -49.61538461538461
# Episode 78  Score -50.0  AVG -49.620253164556964
# Episode 79  Score -50.0  AVG -49.625
# Episode 80  Score -50.0  AVG -49.629629629629626
# Episode 81  Score -50.0  AVG -49.63414634146341
# Episode 82  Score -50.0  AVG -49.63855421686747
# Episode 83  Score -50.0  AVG -49.642857142857146
# Episode 84  Score -50.0  AVG -49.64705882352941
# Episode 85  Score -50.0  AVG -49.651162790697676
# Episode 86  Score -50.0  AVG -49.6551724137931
# Episode 87  Score -50.0  AVG -49.65909090909091
# Episode 88  Score -50.0  AVG -49.662921348314605
# Episode 89  Score -50.0  AVG -49.666666666666664
# Episode 90  Score -50.0  AVG -49.67032967032967
# Episode 91  Score -50.0  AVG -49.67391304347826
# Episode 92  Score -50.0  AVG -49.67741935483871
# Episode 93  Score -50.0  AVG -49.680851063829785
# Episode 94  Score -50.0  AVG -49.68421052631579
# Episode 95  Score -50.0  AVG -49.6875
# Episode 96  Score -50.0  AVG -49.69072164948454
# Episode 97  Score -50.0  AVG -49.69387755102041
# Episode 98  Score -50.0  AVG -49.696969696969695
# Episode 99  Score -50.0  AVG -49.7
# Episode 100  Score -50.0  AVG -49.7
# Episode 101  Score -29.0  AVG -49.49
# Episode 102  Score -50.0  AVG -49.49
# Episode 103  Score -43.0  AVG -49.42
# Episode 104  Score -50.0  AVG -49.42
# Episode 105  Score -50.0  AVG -49.42
# Episode 106  Score -50.0  AVG -49.42
# Episode 107  Score -50.0  AVG -49.42
# Episode 108  Score -50.0  AVG -49.42
# Episode 109  Score -50.0  AVG -49.42
# Episode 110  Score -50.0  AVG -49.42
# Episode 111  Score -36.0  AVG -49.28
# Episode 112  Score -50.0  AVG -49.28
# Episode 113  Score -50.0  AVG -49.3
# Episode 114  Score -50.0  AVG -49.3
# Episode 115  Score -50.0  AVG -49.3
# Episode 116  Score -50.0  AVG -49.3
# Episode 117  Score -48.0  AVG -49.28
# Episode 118  Score -50.0  AVG -49.28
# Episode 119  Score -50.0  AVG -49.28
# Episode 120  Score -50.0  AVG -49.28
# Episode 121  Score -50.0  AVG -49.28
# Episode 122  Score -50.0  AVG -49.28
# Episode 123  Score -45.0  AVG -49.23
# Episode 124  Score -23.0  AVG -49.07
# Episode 125  Score -50.0  AVG -49.07
# Episode 126  Score -50.0  AVG -49.07
# Episode 127  Score -45.0  AVG -49.02
# Episode 128  Score -50.0  AVG -49.02
# Episode 129  Score -50.0  AVG -49.02
# Episode 130  Score -50.0  AVG -49.02
# Episode 131  Score -50.0  AVG -49.02
# Episode 132  Score -50.0  AVG -49.02
# Episode 133  Score -50.0  AVG -49.02
# Episode 134  Score -50.0  AVG -49.02
# Episode 135  Score -50.0  AVG -49.02
# Episode 136  Score -49.0  AVG -49.01
# Episode 137  Score -50.0  AVG -49.01
# Episode 138  Score -47.0  AVG -48.98
# Episode 139  Score -50.0  AVG -48.98
# Episode 140  Score -46.0  AVG -48.94
# Episode 141  Score -50.0  AVG -48.94
# Episode 142  Score -50.0  AVG -49.01
# Episode 143  Score -50.0  AVG -49.01
# Episode 144  Score -50.0  AVG -49.01
# Episode 145  Score -47.0  AVG -48.98
# Episode 146  Score -47.0  AVG -48.95
# Episode 147  Score -50.0  AVG -48.95
# Episode 148  Score -43.0  AVG -48.88
# Episode 149  Score -42.0  AVG -48.8
# Episode 150  Score -45.0  AVG -48.75
# Episode 151  Score -50.0  AVG -48.75
# Episode 152  Score -50.0  AVG -48.75
# Episode 153  Score -50.0  AVG -48.75
# Episode 154  Score -47.0  AVG -48.72
# Episode 155  Score -25.0  AVG -48.47
# Episode 156  Score -50.0  AVG -48.47
# Episode 157  Score -50.0  AVG -48.47
# Episode 158  Score -28.0  AVG -48.25
# Episode 159  Score -50.0  AVG -48.25
# Episode 160  Score -35.0  AVG -48.1
# Episode 161  Score -50.0  AVG -48.1
# Episode 162  Score -50.0  AVG -48.1
# Episode 163  Score -41.0  AVG -48.01
# Episode 164  Score -50.0  AVG -48.01
# Episode 165  Score -50.0  AVG -48.01
# Episode 166  Score -40.0  AVG -47.91
# Episode 167  Score -41.0  AVG -47.82
# Episode 168  Score -50.0  AVG -47.82
# Episode 169  Score -50.0  AVG -47.82
# Episode 170  Score -50.0  AVG -47.82
# Episode 171  Score -50.0  AVG -47.91
# Episode 172  Score -45.0  AVG -47.86
# Episode 173  Score -43.0  AVG -47.79
# Episode 174  Score -50.0  AVG -47.79
# Episode 175  Score -50.0  AVG -47.79
# Episode 176  Score -50.0  AVG -47.79
# Episode 177  Score -50.0  AVG -47.8
# Episode 178  Score -43.0  AVG -47.73
# Episode 179  Score -50.0  AVG -47.73
# Episode 180  Score -50.0  AVG -47.73
# Episode 181  Score -37.0  AVG -47.6
# Episode 182  Score -15.0  AVG -47.25
# Episode 183  Score -50.0  AVG -47.25
# Episode 184  Score -50.0  AVG -47.25
# Episode 185  Score -50.0  AVG -47.25
# Episode 186  Score -50.0  AVG -47.25
# Episode 187  Score -50.0  AVG -47.25
# Episode 188  Score -5.0  AVG -46.8
# Episode 189  Score -50.0  AVG -46.8
# Episode 190  Score -50.0  AVG -46.8
# Episode 191  Score -50.0  AVG -46.8
# Episode 192  Score -28.0  AVG -46.58
# Episode 193  Score -49.0  AVG -46.57
# Episode 194  Score -50.0  AVG -46.57
# Episode 195  Score -31.0  AVG -46.38
# Episode 196  Score -50.0  AVG -46.38
# Episode 197  Score -50.0  AVG -46.38
# Episode 198  Score -50.0  AVG -46.38
# Episode 199  Score -50.0  AVG -46.38
# Episode 200  Score -50.0  AVG -46.38
# Episode 201  Score -50.0  AVG -46.59
# Episode 202  Score -50.0  AVG -46.59
# Episode 203  Score -50.0  AVG -46.66
# Episode 204  Score -50.0  AVG -46.66
# Episode 205  Score -50.0  AVG -46.66
# Episode 206  Score -50.0  AVG -46.66
# Episode 207  Score -50.0  AVG -46.66
# Episode 208  Score -50.0  AVG -46.66
# Episode 209  Score -50.0  AVG -46.66
# Episode 210  Score -50.0  AVG -46.66
# Episode 211  Score -50.0  AVG -46.8
# Episode 212  Score -50.0  AVG -46.8
# Episode 213  Score -49.0  AVG -46.79
# Episode 214  Score -50.0  AVG -46.79
# Episode 215  Score -50.0  AVG -46.79
# Episode 216  Score -50.0  AVG -46.79
# Episode 217  Score -50.0  AVG -46.81
# Episode 218  Score -47.0  AVG -46.78
# Episode 219  Score -50.0  AVG -46.78
# Episode 220  Score -48.0  AVG -46.76
# Episode 221  Score -3.0  AVG -46.29
# Episode 222  Score -50.0  AVG -46.29
# Episode 223  Score -50.0  AVG -46.34
# Episode 224  Score -48.0  AVG -46.59
# Episode 225  Score -50.0  AVG -46.59
# Episode 226  Score -50.0  AVG -46.59
# Episode 227  Score -41.0  AVG -46.55
# Episode 228  Score -50.0  AVG -46.55
# Episode 229  Score -50.0  AVG -46.55
# Episode 230  Score -36.0  AVG -46.41
# Episode 231  Score -50.0  AVG -46.41
# Episode 232  Score -50.0  AVG -46.41
# Episode 233  Score -39.0  AVG -46.3
# Episode 234  Score -50.0  AVG -46.3
# Episode 235  Score -45.0  AVG -46.25
# Episode 236  Score -50.0  AVG -46.26
# Episode 237  Score -50.0  AVG -46.26
# Episode 238  Score -50.0  AVG -46.29
# Episode 239  Score -38.0  AVG -46.17
# Episode 240  Score -50.0  AVG -46.21
# Episode 241  Score -50.0  AVG -46.21
# Episode 242  Score -16.0  AVG -45.87
# Episode 243  Score -47.0  AVG -45.84
# Episode 244  Score -42.0  AVG -45.76
# Episode 245  Score -50.0  AVG -45.79
# Episode 246  Score -30.0  AVG -45.62
# Episode 247  Score -29.0  AVG -45.41
# Episode 248  Score -50.0  AVG -45.48
# Episode 249  Score -50.0  AVG -45.56
# Episode 250  Score -6.0  AVG -45.17
# Episode 251  Score -39.0  AVG -45.06
# Episode 252  Score -28.0  AVG -44.84
# Episode 253  Score -25.0  AVG -44.59
# Episode 254  Score -15.0  AVG -44.27
# Episode 255  Score -37.0  AVG -44.39
# Episode 256  Score -39.0  AVG -44.28
# Episode 257  Score -42.0  AVG -44.2
# Episode 258  Score -50.0  AVG -44.42
# Episode 259  Score -50.0  AVG -44.42
# Episode 260  Score -50.0  AVG -44.57
# Episode 261  Score -14.0  AVG -44.21
# Episode 262  Score -47.0  AVG -44.18
# Episode 263  Score -36.0  AVG -44.13
# Episode 264  Score -50.0  AVG -44.13
# Episode 265  Score -40.0  AVG -44.03
# Episode 266  Score -50.0  AVG -44.13
# Episode 267  Score -50.0  AVG -44.22
# Episode 268  Score -50.0  AVG -44.22
# Episode 269  Score -30.0  AVG -44.02
# Episode 270  Score -38.0  AVG -43.9
# Episode 271  Score -18.0  AVG -43.58
# Episode 272  Score -50.0  AVG -43.63
# Episode 273  Score -50.0  AVG -43.7
# Episode 274  Score -34.0  AVG -43.54
# Episode 275  Score -37.0  AVG -43.41
# Episode 276  Score -46.0  AVG -43.37
# Episode 277  Score -42.0  AVG -43.29
# Episode 278  Score -38.0  AVG -43.24
# Episode 279  Score -19.0  AVG -42.93
# Episode 280  Score -50.0  AVG -42.93
# Episode 281  Score -23.0  AVG -42.79
# Episode 282  Score -30.0  AVG -42.94
# Episode 283  Score -16.0  AVG -42.6
# Episode 284  Score -43.0  AVG -42.53
# Episode 285  Score -50.0  AVG -42.53
# Episode 286  Score -47.0  AVG -42.5
# Episode 287  Score -50.0  AVG -42.5
# Episode 288  Score -50.0  AVG -42.95
# Episode 289  Score -41.0  AVG -42.86
# Episode 290  Score -38.0  AVG -42.74
# Episode 291  Score -50.0  AVG -42.74
# Episode 292  Score -50.0  AVG -42.96
# Episode 293  Score -30.0  AVG -42.77
# Episode 294  Score -50.0  AVG -42.77
# Episode 295  Score -48.0  AVG -42.94
# Episode 296  Score -9.0  AVG -42.53
# Episode 297  Score -33.0  AVG -42.36
# Episode 298  Score -40.0  AVG -42.26
# Episode 299  Score -38.0  AVG -42.14
# Episode 300  Score -35.0  AVG -41.99
# Episode 301  Score -50.0  AVG -41.99
# Episode 302  Score -40.0  AVG -41.89
# Episode 303  Score -32.0  AVG -41.71
# Episode 304  Score -30.0  AVG -41.51
# Episode 305  Score -44.0  AVG -41.45
# Episode 306  Score -24.0  AVG -41.19
# Episode 307  Score -37.0  AVG -41.06
# Episode 308  Score -36.0  AVG -40.92
# Episode 309  Score -42.0  AVG -40.84
# Episode 310  Score -22.0  AVG -40.56
# Episode 311  Score -33.0  AVG -40.39
# Episode 312  Score -32.0  AVG -40.21
# Episode 313  Score -13.0  AVG -39.85
# Episode 314  Score -35.0  AVG -39.7
# Episode 315  Score -19.0  AVG -39.39
# Episode 316  Score -16.0  AVG -39.05
# Episode 317  Score -3.0  AVG -38.58
# Episode 318  Score -24.0  AVG -38.35
# Episode 319  Score -8.0  AVG -37.93
# Episode 320  Score -37.0  AVG -37.82
# Episode 321  Score -50.0  AVG -38.29
# Episode 322  Score -50.0  AVG -38.29
# Episode 323  Score -50.0  AVG -38.29
# Episode 324  Score -50.0  AVG -38.31
# Episode 325  Score -50.0  AVG -38.31
# Episode 326  Score -50.0  AVG -38.31
# Episode 327  Score -50.0  AVG -38.4
# Episode 328  Score -50.0  AVG -38.4
# Episode 329  Score -18.0  AVG -38.08
# Episode 330  Score -50.0  AVG -38.22
# Episode 331  Score -50.0  AVG -38.22
# Episode 332  Score -50.0  AVG -38.22
# Episode 333  Score -49.0  AVG -38.32
# Episode 334  Score -48.0  AVG -38.3
# Episode 335  Score -50.0  AVG -38.35
# Episode 336  Score -50.0  AVG -38.35
# Episode 337  Score -50.0  AVG -38.35
# Episode 338  Score -42.0  AVG -38.27
# Episode 339  Score -24.0  AVG -38.13
# Episode 340  Score -20.0  AVG -37.83
# Episode 341  Score -46.0  AVG -37.79
# Episode 342  Score -28.0  AVG -37.91
# Episode 343  Score -38.0  AVG -37.82
# Episode 344  Score -2.0  AVG -37.42
# Episode 345  Score -40.0  AVG -37.32
# Episode 346  Score -37.0  AVG -37.39
# Episode 347  Score -19.0  AVG -37.29
# Episode 348  Score -37.0  AVG -37.16
# Episode 349  Score -50.0  AVG -37.16
# Episode 350  Score -27.0  AVG -37.37
# Episode 351  Score -31.0  AVG -37.29
# Episode 352  Score -28.0  AVG -37.29
# Episode 353  Score -7.0  AVG -37.11
# Episode 354  Score -8.0  AVG -37.04
# Episode 355  Score -36.0  AVG -37.03
# Episode 356  Score -5.0  AVG -36.69
# Episode 357  Score -2.0  AVG -36.29
# Episode 358  Score -17.0  AVG -35.96
# Episode 359  Score -14.0  AVG -35.6
# Episode 360  Score -5.0  AVG -35.15
# Episode 361  Score -31.0  AVG -35.32
# Episode 362  Score -18.0  AVG -35.03
# Episode 363  Score -24.0  AVG -34.91
# Episode 364  Score -11.0  AVG -34.52
# Episode 365  Score -20.0  AVG -34.32
# Episode 366  Score -17.0  AVG -33.99
# Episode 367  Score -9.0  AVG -33.58
# Episode 368  Score -22.0  AVG -33.3
# Episode 369  Score -6.0  AVG -33.06
# Episode 370  Score -25.0  AVG -32.93
# Episode 371  Score -17.0  AVG -32.92
# Episode 372  Score -21.0  AVG -32.63
# Episode 373  Score -28.0  AVG -32.41
# Episode 374  Score -23.0  AVG -32.3
# Episode 375  Score -27.0  AVG -32.2
# Episode 376  Score -39.0  AVG -32.13
# Episode 377  Score -15.0  AVG -31.86
# Episode 378  Score -8.0  AVG -31.56
# Episode 379  Score -8.0  AVG -31.45
# Episode 380  Score -25.0  AVG -31.2
# Episode 381  Score -9.0  AVG -31.06
# Episode 382  Score -8.0  AVG -30.84
# Episode 383  Score -15.0  AVG -30.83
# Episode 384  Score -20.0  AVG -30.6
# Episode 385  Score -15.0  AVG -30.25
# Episode 386  Score -16.0  AVG -29.94
# Episode 387  Score -21.0  AVG -29.65
# Episode 388  Score -36.0  AVG -29.51
# Episode 389  Score -32.0  AVG -29.42
# Episode 390  Score -4.0  AVG -29.08
# Episode 391  Score -3.0  AVG -28.61
# Episode 392  Score -1.0  AVG -28.12
# Episode 393  Score -23.0  AVG -28.05
# Episode 394  Score -26.0  AVG -27.81
# Episode 395  Score -23.0  AVG -27.56
# Episode 396  Score -29.0  AVG -27.76
# Episode 397  Score -13.0  AVG -27.56
# Episode 398  Score -2.0  AVG -27.18
# Episode 399  Score -6.0  AVG -26.86
# Episode 400  Score -15.0  AVG -26.66
# Episode 401  Score -29.0  AVG -26.45
# Episode 402  Score -13.0  AVG -26.18
# Episode 403  Score -11.0  AVG -25.97
# Episode 404  Score -21.0  AVG -25.88
# Episode 405  Score -27.0  AVG -25.71
# Episode 406  Score -28.0  AVG -25.75
# Episode 407  Score 0.0  AVG -25.38
# Episode 408  Score -6.0  AVG -25.08
# Episode 409  Score -8.0  AVG -24.74
# Episode 410  Score -35.0  AVG -24.87
# Episode 411  Score -21.0  AVG -24.75
# Episode 412  Score -16.0  AVG -24.59
# Episode 413  Score -13.0  AVG -24.59
# Episode 414  Score -38.0  AVG -24.62
# Episode 415  Score -21.0  AVG -24.64
# Episode 416  Score -8.0  AVG -24.56
# Episode 417  Score -11.0  AVG -24.64
# Episode 418  Score -2.0  AVG -24.42
# Episode 419  Score -5.0  AVG -24.39
# Episode 420  Score -24.0  AVG -24.26
# Episode 421  Score -34.0  AVG -24.1
# Episode 422  Score -11.0  AVG -23.71
# Episode 423  Score -4.0  AVG -23.25
# Episode 424  Score 0.0  AVG -22.75
# Episode 425  Score -3.0  AVG -22.28
# Episode 426  Score -3.0  AVG -21.81
# Episode 427  Score -6.0  AVG -21.37
# Episode 428  Score -2.0  AVG -20.89
# Episode 429  Score -8.0  AVG -20.79
# Episode 430  Score -24.0  AVG -20.53
# Episode 431  Score -6.0  AVG -20.09
# Episode 432  Score 0.0  AVG -19.59
# Episode 433  Score 0.0  AVG -19.1
# Episode 434  Score -4.0  AVG -18.66
# Episode 435  Score -3.0  AVG -18.19
# Episode 436  Score -35.0  AVG -18.04
# Episode 437  Score -33.0  AVG -17.87
# Episode 438  Score 0.0  AVG -17.45
# Episode 439  Score -1.0  AVG -17.22
# Episode 440  Score -7.0  AVG -17.09
# Episode 441  Score -3.0  AVG -16.66
# Episode 442  Score -10.0  AVG -16.48
# Episode 443  Score -1.0  AVG -16.11
# Episode 444  Score -7.0  AVG -16.16
# Episode 445  Score -3.0  AVG -15.79
# Episode 446  Score -1.0  AVG -15.43
# Episode 447  Score -5.0  AVG -15.29
# Episode 448  Score -9.0  AVG -15.01
# Episode 449  Score -20.0  AVG -14.71
# Episode 450  Score -2.0  AVG -14.46
# Episode 451  Score -2.0  AVG -14.17
# Episode 452  Score -17.0  AVG -14.06
# Episode 453  Score -2.0  AVG -14.01
# Episode 454  Score -3.0  AVG -13.96
# Episode 455  Score -4.0  AVG -13.64
# Episode 456  Score -29.0  AVG -13.88
# Episode 457  Score -12.0  AVG -13.98
# Episode 458  Score -3.0  AVG -13.84
# Episode 459  Score -2.0  AVG -13.72
# Episode 460  Score -11.0  AVG -13.78
# Episode 461  Score -1.0  AVG -13.48
# Episode 462  Score -3.0  AVG -13.33
# Episode 463  Score -27.0  AVG -13.36
# Episode 464  Score -16.0  AVG -13.41
# Episode 465  Score -13.0  AVG -13.34
# Episode 466  Score -10.0  AVG -13.27
# Episode 467  Score -2.0  AVG -13.2
# Episode 468  Score -17.0  AVG -13.15
# Episode 469  Score -10.0  AVG -13.19
# Episode 470  Score -3.0  AVG -12.97
# Episode 471  Score -2.0  AVG -12.82
# Episode 472  Score -2.0  AVG -12.63
# Episode 473  Score 0.0  AVG -12.35
# Episode 474  Score -20.0  AVG -12.32
# Episode 475  Score -13.0  AVG -12.18
# Episode 476  Score -14.0  AVG -11.93
# Episode 477  Score -3.0  AVG -11.81
# Episode 478  Score -3.0  AVG -11.76
# Episode 479  Score -3.0  AVG -11.71
# Episode 480  Score -3.0  AVG -11.49
# Episode 481  Score -2.0  AVG -11.42
# Episode 482  Score -1.0  AVG -11.35
# Episode 483  Score -5.0  AVG -11.25
# Episode 484  Score -2.0  AVG -11.07
# Episode 485  Score -10.0  AVG -11.02
# Episode 486  Score -3.0  AVG -10.89
# Episode 487  Score -44.0  AVG -11.12
# Episode 488  Score -34.0  AVG -11.1
# Episode 489  Score -16.0  AVG -10.94
# Episode 490  Score -8.0  AVG -10.98
# Episode 491  Score -1.0  AVG -10.96
# Episode 492  Score -2.0  AVG -10.97
# Episode 493  Score -6.0  AVG -10.8
# Episode 494  Score -3.0  AVG -10.57
# Episode 495  Score -3.0  AVG -10.37
# Episode 496  Score -1.0  AVG -10.09
# Episode 497  Score 0.0  AVG -9.96
# Episode 498  Score -3.0  AVG -9.97
# Episode 499  Score -12.0  AVG -10.03
# Episode 500  Score -7.0  AVG -9.95
# Episode 501  Score -1.0  AVG -9.67
# Episode 502  Score 0.0  AVG -9.54
# Episode 503  Score -1.0  AVG -9.44
# Episode 504  Score -3.0  AVG -9.26
# Episode 505  Score -1.0  AVG -9.0
# Episode 506  Score -7.0  AVG -8.79
# Episode 507  Score -2.0  AVG -8.81
# Episode 508  Score 0.0  AVG -8.75
# Episode 509  Score -3.0  AVG -8.7
# Episode 510  Score -2.0  AVG -8.37
# Episode 511  Score -2.0  AVG -8.18
# Episode 512  Score -1.0  AVG -8.03
# Episode 513  Score -15.0  AVG -8.05
# Episode 514  Score -11.0  AVG -7.78
# Episode 515  Score 0.0  AVG -7.57
# Episode 516  Score -1.0  AVG -7.5
# Episode 517  Score -2.0  AVG -7.41
# Episode 518  Score -1.0  AVG -7.4
# Episode 519  Score -2.0  AVG -7.37
# Episode 520  Score -2.0  AVG -7.15
# Episode 521  Score -2.0  AVG -6.83
# Episode 522  Score -3.0  AVG -6.75
# Episode 523  Score 0.0  AVG -6.71
# Episode 524  Score -2.0  AVG -6.73
# Episode 525  Score -1.0  AVG -6.71
# Episode 526  Score -7.0  AVG -6.75
# Episode 527  Score -6.0  AVG -6.75
# Episode 528  Score -1.0  AVG -6.74
# Episode 529  Score -3.0  AVG -6.69
# Episode 530  Score -38.0  AVG -6.83
# Episode 531  Score -22.0  AVG -6.99
# Episode 532  Score -3.0  AVG -7.02
# Episode 533  Score -4.0  AVG -7.06
# Episode 534  Score -11.0  AVG -7.13
# Episode 535  Score -1.0  AVG -7.11
# Episode 536  Score -2.0  AVG -6.78
# Episode 537  Score -2.0  AVG -6.47
# Episode 538  Score -3.0  AVG -6.5
# Episode 539  Score -3.0  AVG -6.52
# Episode 540  Score -3.0  AVG -6.48
# Episode 541  Score -2.0  AVG -6.47
# Episode 542  Score -2.0  AVG -6.39
# Episode 543  Score -3.0  AVG -6.41
# Episode 544  Score -3.0  AVG -6.37
# Episode 545  Score -1.0  AVG -6.35
# Episode 546  Score -3.0  AVG -6.37
# Episode 547  Score -1.0  AVG -6.33
# Episode 548  Score -1.0  AVG -6.25
# Episode 549  Score 0.0  AVG -6.05
# Episode 550  Score -2.0  AVG -6.05
# Episode 551  Score -3.0  AVG -6.06
# Episode 552  Score -2.0  AVG -5.91
# Episode 553  Score -14.0  AVG -6.03
# Episode 554  Score -1.0  AVG -6.01
# Episode 555  Score -3.0  AVG -6.0
# Episode 556  Score -1.0  AVG -5.72
# Episode 557  Score -2.0  AVG -5.62
# Episode 558  Score -10.0  AVG -5.69
# Episode 559  Score -7.0  AVG -5.74
# Episode 560  Score -2.0  AVG -5.65
# Episode 561  Score 0.0  AVG -5.64
# Episode 562  Score -21.0  AVG -5.82
# Episode 563  Score -30.0  AVG -5.85
# Episode 564  Score -28.0  AVG -5.97
# Episode 565  Score -1.0  AVG -5.85
# Episode 566  Score -7.0  AVG -5.82
# Episode 567  Score -2.0  AVG -5.82
# Episode 568  Score -47.0  AVG -6.12
# Episode 569  Score -8.0  AVG -6.1
# Episode 570  Score -31.0  AVG -6.38
# Episode 571  Score -22.0  AVG -6.58
# Episode 572  Score -10.0  AVG -6.66
# Episode 573  Score -1.0  AVG -6.67
# Episode 574  Score -2.0  AVG -6.49
# Episode 575  Score -2.0  AVG -6.38
# Episode 576  Score -2.0  AVG -6.26
# Episode 577  Score -11.0  AVG -6.34
# Episode 578  Score -2.0  AVG -6.33
# Episode 579  Score 0.0  AVG -6.3
# Episode 580  Score -2.0  AVG -6.29
# Episode 581  Score -2.0  AVG -6.29
# Episode 582  Score -7.0  AVG -6.35
# Episode 583  Score -2.0  AVG -6.32
# Episode 584  Score -2.0  AVG -6.32
# Episode 585  Score -5.0  AVG -6.27
# Episode 586  Score -9.0  AVG -6.33
# Episode 587  Score -2.0  AVG -5.91
# Episode 588  Score -2.0  AVG -5.59
# Episode 589  Score -2.0  AVG -5.45
# Episode 590  Score -2.0  AVG -5.39
# Episode 591  Score -1.0  AVG -5.39
# Episode 592  Score -3.0  AVG -5.4
# Episode 593  Score -1.0  AVG -5.35
# Episode 594  Score -3.0  AVG -5.35
# Episode 595  Score -1.0  AVG -5.33
# Episode 596  Score -3.0  AVG -5.35
# Episode 597  Score -3.0  AVG -5.38
# Episode 598  Score -2.0  AVG -5.37
# Episode 599  Score -2.0  AVG -5.27
# Episode 600  Score -2.0  AVG -5.22
# Episode 601  Score -2.0  AVG -5.23
# Episode 602  Score -1.0  AVG -5.24
# Episode 603  Score -1.0  AVG -5.24
# Episode 604  Score -1.0  AVG -5.22
# Episode 605  Score -5.0  AVG -5.26
# Episode 606  Score -2.0  AVG -5.21
# Episode 607  Score -3.0  AVG -5.22
# Episode 608  Score -1.0  AVG -5.23
# Episode 609  Score -2.0  AVG -5.22
# Episode 610  Score 0.0  AVG -5.2
# Episode 611  Score 0.0  AVG -5.18
# Episode 612  Score -15.0  AVG -5.32
# Episode 613  Score -30.0  AVG -5.47
# Episode 614  Score -2.0  AVG -5.38
# Episode 615  Score -7.0  AVG -5.45
# Episode 616  Score -9.0  AVG -5.53
# Episode 617  Score -9.0  AVG -5.6
# Episode 618  Score -19.0  AVG -5.78
# Episode 619  Score -6.0  AVG -5.82
# Episode 620  Score 0.0  AVG -5.8
# Episode 621  Score -18.0  AVG -5.96
# Episode 622  Score -6.0  AVG -5.99
# Episode 623  Score -28.0  AVG -6.27
# Episode 624  Score -1.0  AVG -6.26
# Episode 625  Score 0.0  AVG -6.25
# Episode 626  Score -1.0  AVG -6.19
# Episode 627  Score -2.0  AVG -6.15
# Episode 628  Score -2.0  AVG -6.16
# Episode 629  Score -2.0  AVG -6.15
# Episode 630  Score -2.0  AVG -5.79
# Episode 631  Score -2.0  AVG -5.59
# Episode 632  Score -3.0  AVG -5.59
# Episode 633  Score -2.0  AVG -5.57
# Episode 634  Score -2.0  AVG -5.48
# Episode 635  Score -3.0  AVG -5.5
# Episode 636  Score -2.0  AVG -5.5
# Episode 637  Score -6.0  AVG -5.54
# Episode 638  Score 0.0  AVG -5.51
# Episode 639  Score -2.0  AVG -5.5
# Episode 640  Score -2.0  AVG -5.49
# Episode 641  Score -2.0  AVG -5.49
# Episode 642  Score -1.0  AVG -5.48
# Episode 643  Score -3.0  AVG -5.48
# Episode 644  Score -1.0  AVG -5.46
# Episode 645  Score -2.0  AVG -5.47
# Episode 646  Score -3.0  AVG -5.47
# Episode 647  Score -1.0  AVG -5.47
# Episode 648  Score -2.0  AVG -5.48
# Episode 649  Score -1.0  AVG -5.49
# Episode 650  Score -2.0  AVG -5.49
# Episode 651  Score 0.0  AVG -5.46
# Episode 652  Score 0.0  AVG -5.44
# Episode 653  Score -2.0  AVG -5.32
# Episode 654  Score 0.0  AVG -5.31
# Episode 655  Score -2.0  AVG -5.3
# Episode 656  Score -2.0  AVG -5.31
# Episode 657  Score -3.0  AVG -5.32
# Episode 658  Score -2.0  AVG -5.24
# Episode 659  Score -12.0  AVG -5.29
# Episode 660  Score -2.0  AVG -5.29
# Episode 661  Score -1.0  AVG -5.3
# Episode 662  Score -2.0  AVG -5.11
# Episode 663  Score -2.0  AVG -4.83
# Episode 664  Score -1.0  AVG -4.56
# Episode 665  Score -1.0  AVG -4.56
# Episode 666  Score -9.0  AVG -4.58
# Episode 667  Score -9.0  AVG -4.65
# Episode 668  Score -1.0  AVG -4.19
# Episode 669  Score -3.0  AVG -4.14
# Episode 670  Score -1.0  AVG -3.84
# Episode 671  Score -1.0  AVG -3.63
# Episode 672  Score -12.0  AVG -3.65
# Episode 673  Score -1.0  AVG -3.65
# Episode 674  Score 0.0  AVG -3.63
# Episode 675  Score -1.0  AVG -3.62
# Episode 676  Score -3.0  AVG -3.63
# Episode 677  Score -2.0  AVG -3.54
# Episode 678  Score -3.0  AVG -3.55
# Episode 679  Score -1.0  AVG -3.56
# Episode 680  Score -1.0  AVG -3.55
# Episode 681  Score -1.0  AVG -3.54
# Episode 682  Score -1.0  AVG -3.48
# Episode 683  Score 0.0  AVG -3.46
# Episode 684  Score -1.0  AVG -3.45
# Episode 685  Score -2.0  AVG -3.42
# Episode 686  Score -3.0  AVG -3.36
# Episode 687  Score -3.0  AVG -3.37
# Episode 688  Score -1.0  AVG -3.36
# Episode 689  Score -2.0  AVG -3.36
# Episode 690  Score -3.0  AVG -3.37
# Episode 691  Score -2.0  AVG -3.38
# Episode 692  Score -3.0  AVG -3.38
# Episode 693  Score -2.0  AVG -3.39
# Episode 694  Score -18.0  AVG -3.54
# Episode 695  Score -3.0  AVG -3.56
# Episode 696  Score -2.0  AVG -3.55
# Episode 697  Score -2.0  AVG -3.54
# Episode 698  Score -3.0  AVG -3.55
# Episode 699  Score -2.0  AVG -3.55
# Episode 700  Score -2.0  AVG -3.55
# Episode 701  Score 0.0  AVG -3.53
# Episode 702  Score -2.0  AVG -3.54
# Episode 703  Score -6.0  AVG -3.59
# Episode 704  Score -2.0  AVG -3.6
# Episode 705  Score -1.0  AVG -3.56
# Episode 706  Score -1.0  AVG -3.55
# Episode 707  Score -2.0  AVG -3.54
# Episode 708  Score -2.0  AVG -3.55
# Episode 709  Score -2.0  AVG -3.55
# Episode 710  Score -1.0  AVG -3.56
# Episode 711  Score -3.0  AVG -3.59
# Episode 712  Score -3.0  AVG -3.47
# Episode 713  Score 0.0  AVG -3.17
# Episode 714  Score 0.0  AVG -3.15
# Episode 715  Score -1.0  AVG -3.09
# Episode 716  Score -2.0  AVG -3.02
# Episode 717  Score -1.0  AVG -2.94
# Episode 718  Score -3.0  AVG -2.78
# Episode 719  Score -21.0  AVG -2.93
# Episode 720  Score -9.0  AVG -3.02
# Episode 721  Score -2.0  AVG -2.86
# Episode 722  Score -2.0  AVG -2.82
# Episode 723  Score -3.0  AVG -2.57
# Episode 724  Score -5.0  AVG -2.61
# Episode 725  Score -9.0  AVG -2.7
# Episode 726  Score -14.0  AVG -2.83
# Episode 727  Score -5.0  AVG -2.86
# Episode 728  Score -1.0  AVG -2.85
# Episode 729  Score -6.0  AVG -2.89
# Episode 730  Score -2.0  AVG -2.89
# Episode 731  Score 0.0  AVG -2.87
# Episode 732  Score -2.0  AVG -2.86
# Episode 733  Score -3.0  AVG -2.87
# Episode 734  Score -12.0  AVG -2.97
# Episode 735  Score -3.0  AVG -2.97
# Episode 736  Score -2.0  AVG -2.97
# Episode 737  Score 0.0  AVG -2.91
# Episode 738  Score -1.0  AVG -2.92
# Episode 739  Score -1.0  AVG -2.91
# Episode 740  Score -2.0  AVG -2.91
# Episode 741  Score -6.0  AVG -2.95
# Episode 742  Score -2.0  AVG -2.96
# Episode 743  Score -3.0  AVG -2.96
# Episode 744  Score -2.0  AVG -2.97
# Episode 745  Score -10.0  AVG -3.05
# Episode 746  Score -3.0  AVG -3.05
# Episode 747  Score -2.0  AVG -3.06
# Episode 748  Score -17.0  AVG -3.21
# Episode 749  Score -2.0  AVG -3.22
# Episode 750  Score -2.0  AVG -3.22
# Episode 751  Score -2.0  AVG -3.24
# Episode 752  Score -2.0  AVG -3.26
# Episode 753  Score -1.0  AVG -3.25
# Episode 754  Score -2.0  AVG -3.27
# Episode 755  Score -3.0  AVG -3.28
# Episode 756  Score -12.0  AVG -3.38
# Episode 757  Score -2.0  AVG -3.37
# Episode 758  Score -2.0  AVG -3.37
# Episode 759  Score -3.0  AVG -3.28
# Episode 760  Score -18.0  AVG -3.44
# Episode 761  Score -1.0  AVG -3.44
# Episode 762  Score -2.0  AVG -3.44
# Episode 763  Score -7.0  AVG -3.49
# Episode 764  Score -2.0  AVG -3.5
# Episode 765  Score -1.0  AVG -3.5
# Episode 766  Score -2.0  AVG -3.43
# Episode 767  Score -3.0  AVG -3.37
# Episode 768  Score -2.0  AVG -3.38
# Episode 769  Score -1.0  AVG -3.36
# Episode 770  Score -2.0  AVG -3.37
# Episode 771  Score -2.0  AVG -3.38
# Episode 772  Score -2.0  AVG -3.28
# Episode 773  Score -1.0  AVG -3.28
# Episode 774  Score -2.0  AVG -3.3
# Episode 775  Score -2.0  AVG -3.31
# Episode 776  Score -1.0  AVG -3.29
# Episode 777  Score -2.0  AVG -3.29
# Episode 778  Score 0.0  AVG -3.26
# Episode 779  Score -2.0  AVG -3.27
# Episode 780  Score -1.0  AVG -3.27
# Episode 781  Score -10.0  AVG -3.36
# Episode 782  Score -22.0  AVG -3.57
# Episode 783  Score -8.0  AVG -3.65
# Episode 784  Score -2.0  AVG -3.66
# Episode 785  Score -3.0  AVG -3.67
# Episode 786  Score -2.0  AVG -3.66
# Episode 787  Score -2.0  AVG -3.65
# Episode 788  Score -2.0  AVG -3.66
# Episode 789  Score -2.0  AVG -3.66
# Episode 790  Score 0.0  AVG -3.63
# Episode 791  Score -1.0  AVG -3.62
# Episode 792  Score -3.0  AVG -3.62
# Episode 793  Score -2.0  AVG -3.62
# Episode 794  Score -2.0  AVG -3.46
# Episode 795  Score -2.0  AVG -3.45
# Episode 796  Score -2.0  AVG -3.45
# Episode 797  Score -3.0  AVG -3.46
# Episode 798  Score -2.0  AVG -3.45
# Episode 799  Score -2.0  AVG -3.45
# Episode 800  Score -2.0  AVG -3.45
# Episode 801  Score -4.0  AVG -3.49
# Episode 802  Score -9.0  AVG -3.56
# Episode 803  Score -2.0  AVG -3.52
# Episode 804  Score -3.0  AVG -3.53
# Episode 805  Score -1.0  AVG -3.53
# Episode 806  Score -1.0  AVG -3.53
# Episode 807  Score -1.0  AVG -3.52
# Episode 808  Score -12.0  AVG -3.62
# Episode 809  Score -9.0  AVG -3.69
# Episode 810  Score -1.0  AVG -3.69
# Episode 811  Score -2.0  AVG -3.68
# Episode 812  Score -3.0  AVG -3.68
# Episode 813  Score -2.0  AVG -3.7
# Episode 814  Score 0.0  AVG -3.7
# Episode 815  Score -2.0  AVG -3.71
# Episode 816  Score -1.0  AVG -3.7
# Episode 817  Score -1.0  AVG -3.7
# Episode 818  Score -1.0  AVG -3.68
# Episode 819  Score 0.0  AVG -3.47
# Episode 820  Score -2.0  AVG -3.4
# Episode 821  Score -2.0  AVG -3.4
# Episode 822  Score -5.0  AVG -3.43
# Episode 823  Score -2.0  AVG -3.42
# Episode 824  Score 0.0  AVG -3.37
# Episode 825  Score -3.0  AVG -3.31
# Episode 826  Score -1.0  AVG -3.18
# Episode 827  Score -3.0  AVG -3.16
# Episode 828  Score -2.0  AVG -3.17
# Episode 829  Score -2.0  AVG -3.13
# Episode 830  Score 0.0  AVG -3.11
# Episode 831  Score -2.0  AVG -3.13
# Episode 832  Score -1.0  AVG -3.12
# Episode 833  Score -2.0  AVG -3.11
# Episode 834  Score -2.0  AVG -3.01
# Episode 835  Score 0.0  AVG -2.98
# Episode 836  Score -2.0  AVG -2.98
# Episode 837  Score -2.0  AVG -3.0
# Episode 838  Score -2.0  AVG -3.01
# Episode 839  Score -3.0  AVG -3.03
# Episode 840  Score -1.0  AVG -3.02
# Episode 841  Score -1.0  AVG -2.97
# Episode 842  Score 0.0  AVG -2.95
# Episode 843  Score -3.0  AVG -2.95
# Episode 844  Score -3.0  AVG -2.96
# Episode 845  Score -2.0  AVG -2.88
# Episode 846  Score -1.0  AVG -2.86
# Episode 847  Score -1.0  AVG -2.85
# Episode 848  Score -5.0  AVG -2.73
# Episode 849  Score -19.0  AVG -2.9
# Episode 850  Score -2.0  AVG -2.9
# Episode 851  Score -2.0  AVG -2.9
# Episode 852  Score -2.0  AVG -2.9
# Episode 853  Score -3.0  AVG -2.92
# Episode 854  Score -2.0  AVG -2.92
# Episode 855  Score -3.0  AVG -2.92
# Episode 856  Score 0.0  AVG -2.8
# Episode 857  Score -2.0  AVG -2.8
# Episode 858  Score -3.0  AVG -2.81
# Episode 859  Score -1.0  AVG -2.79
# Episode 860  Score -3.0  AVG -2.64
# Episode 861  Score -6.0  AVG -2.69
# Episode 862  Score -18.0  AVG -2.85
# Episode 863  Score -1.0  AVG -2.79
# Episode 864  Score -3.0  AVG -2.8
# Episode 865  Score -14.0  AVG -2.93
# Episode 866  Score -2.0  AVG -2.93
# Episode 867  Score -2.0  AVG -2.92
# Episode 868  Score -2.0  AVG -2.92
# Episode 869  Score 0.0  AVG -2.91
# Episode 870  Score -3.0  AVG -2.92
# Episode 871  Score -3.0  AVG -2.93
# Episode 872  Score -13.0  AVG -3.04
# Episode 873  Score -1.0  AVG -3.04
# Episode 874  Score -1.0  AVG -3.03
# Episode 875  Score -1.0  AVG -3.02
# Episode 876  Score -2.0  AVG -3.03
# Episode 877  Score -8.0  AVG -3.09
# Episode 878  Score -2.0  AVG -3.11
# Episode 879  Score -1.0  AVG -3.1
# Episode 880  Score -1.0  AVG -3.1
# Episode 881  Score -2.0  AVG -3.02
# Episode 882  Score -2.0  AVG -2.82
# Episode 883  Score -1.0  AVG -2.75
# Episode 884  Score -2.0  AVG -2.75
# Episode 885  Score -1.0  AVG -2.73
# Episode 886  Score -3.0  AVG -2.74
# Episode 887  Score -2.0  AVG -2.74
# Episode 888  Score -2.0  AVG -2.74
# Episode 889  Score -1.0  AVG -2.73
# Episode 890  Score -1.0  AVG -2.74
# Episode 891  Score -1.0  AVG -2.74
# Episode 892  Score 0.0  AVG -2.71
# Episode 893  Score -2.0  AVG -2.71
# Episode 894  Score -1.0  AVG -2.7
# Episode 895  Score -4.0  AVG -2.72
# Episode 896  Score -26.0  AVG -2.96
# Episode 897  Score -2.0  AVG -2.95
# Episode 898  Score -2.0  AVG -2.95
# Episode 899  Score -2.0  AVG -2.95
# Episode 900  Score -3.0  AVG -2.96
# Episode 901  Score -1.0  AVG -2.93
# Episode 902  Score -3.0  AVG -2.87
# Episode 903  Score -3.0  AVG -2.88
# Episode 904  Score -2.0  AVG -2.87
# Episode 905  Score -1.0  AVG -2.87
# Episode 906  Score -9.0  AVG -2.95
# Episode 907  Score -1.0  AVG -2.95
# Episode 908  Score -2.0  AVG -2.85
# Episode 909  Score -3.0  AVG -2.79
# Episode 910  Score -16.0  AVG -2.94
# Episode 911  Score -1.0  AVG -2.93
# Episode 912  Score -2.0  AVG -2.92
# Episode 913  Score -2.0  AVG -2.92
# Episode 914  Score -1.0  AVG -2.93
# Episode 915  Score -26.0  AVG -3.17
# Episode 916  Score -35.0  AVG -3.51
# Episode 917  Score -4.0  AVG -3.54
# Episode 918  Score -1.0  AVG -3.54
# Episode 919  Score -2.0  AVG -3.56
# Episode 920  Score -3.0  AVG -3.57
# Episode 921  Score -2.0  AVG -3.57
# Episode 922  Score -2.0  AVG -3.54
# Episode 923  Score 0.0  AVG -3.52
# Episode 924  Score 0.0  AVG -3.52
# Episode 925  Score -2.0  AVG -3.51
# Episode 926  Score -2.0  AVG -3.52
# Episode 927  Score -2.0  AVG -3.51
# Episode 928  Score -3.0  AVG -3.52
# Episode 929  Score -1.0  AVG -3.51
# Episode 930  Score -9.0  AVG -3.6
# Episode 931  Score -4.0  AVG -3.62
# Episode 932  Score -3.0  AVG -3.64
# Episode 933  Score 0.0  AVG -3.62
# Episode 934  Score -3.0  AVG -3.63
# Episode 935  Score -4.0  AVG -3.67
# Episode 936  Score -2.0  AVG -3.67
# Episode 937  Score -3.0  AVG -3.68
# Episode 938  Score -2.0  AVG -3.68
# Episode 939  Score -3.0  AVG -3.68
# Episode 940  Score -2.0  AVG -3.69
# Episode 941  Score -2.0  AVG -3.7
# Episode 942  Score -2.0  AVG -3.72
# Episode 943  Score 0.0  AVG -3.69
# Episode 944  Score -1.0  AVG -3.67
# Episode 945  Score -1.0  AVG -3.66
# Episode 946  Score -2.0  AVG -3.67
# Episode 947  Score 0.0  AVG -3.66
# Episode 948  Score -3.0  AVG -3.64
# Episode 949  Score -3.0  AVG -3.48
# Episode 950  Score -2.0  AVG -3.48
# Episode 951  Score -1.0  AVG -3.47
# Episode 952  Score -2.0  AVG -3.47
# Episode 953  Score -2.0  AVG -3.46
# Episode 954  Score 0.0  AVG -3.44
# Episode 955  Score -3.0  AVG -3.44
# Episode 956  Score -1.0  AVG -3.45
# Episode 957  Score -2.0  AVG -3.45
# Episode 958  Score -3.0  AVG -3.45
# Episode 959  Score -2.0  AVG -3.46
# Episode 960  Score -2.0  AVG -3.45
# Episode 961  Score -2.0  AVG -3.41
# Episode 962  Score -3.0  AVG -3.26
# Episode 963  Score -2.0  AVG -3.27
# Episode 964  Score -3.0  AVG -3.27
# Episode 965  Score -3.0  AVG -3.16
# Episode 966  Score -3.0  AVG -3.17
# Episode 967  Score -1.0  AVG -3.16
# Episode 968  Score 0.0  AVG -3.14
# Episode 969  Score -1.0  AVG -3.15
# Episode 970  Score -1.0  AVG -3.13
# Episode 971  Score -16.0  AVG -3.26
# Episode 972  Score -13.0  AVG -3.26
# Episode 973  Score -3.0  AVG -3.28
# Episode 974  Score -2.0  AVG -3.29
# Episode 975  Score -2.0  AVG -3.3
# Episode 976  Score -2.0  AVG -3.3
# Episode 977  Score -3.0  AVG -3.25
# Episode 978  Score -3.0  AVG -3.26
# Episode 979  Score -3.0  AVG -3.28
# Episode 980  Score -1.0  AVG -3.28
# Episode 981  Score -2.0  AVG -3.28
# Episode 982  Score -3.0  AVG -3.29
# Episode 983  Score -2.0  AVG -3.3
# Episode 984  Score -1.0  AVG -3.29
# Episode 985  Score -1.0  AVG -3.29
# Episode 986  Score -2.0  AVG -3.28
# Episode 987  Score -3.0  AVG -3.29
# Episode 988  Score -2.0  AVG -3.29
# Episode 989  Score -10.0  AVG -3.38
# Episode 990  Score -3.0  AVG -3.4
# Episode 991  Score -3.0  AVG -3.42
# Episode 992  Score -2.0  AVG -3.44
# Episode 993  Score -1.0  AVG -3.43
# Episode 994  Score -6.0  AVG -3.48
# Episode 995  Score -2.0  AVG -3.46
# Episode 996  Score -2.0  AVG -3.22
# Episode 997  Score -1.0  AVG -3.21
# Episode 998  Score -2.0  AVG -3.21
# Episode 999  Score -1.0  AVG -3.2
# Episode 1000  Score -2.0  AVG -3.19
# Episode 1001  Score -2.0  AVG -3.2
# Episode 1002  Score 0.0  AVG -3.17
# Episode 1003  Score -3.0  AVG -3.17
# Episode 1004  Score -2.0  AVG -3.17
# Episode 1005  Score -1.0  AVG -3.17
# Episode 1006  Score -2.0  AVG -3.1
# Episode 1007  Score -2.0  AVG -3.11
# Episode 1008  Score -1.0  AVG -3.1
# Episode 1009  Score -1.0  AVG -3.08
# Episode 1010  Score -8.0  AVG -3.0
# Episode 1011  Score -4.0  AVG -3.03
# Episode 1012  Score -28.0  AVG -3.29
# Episode 1013  Score -7.0  AVG -3.34
# Episode 1014  Score -2.0  AVG -3.35
# Episode 1015  Score -1.0  AVG -3.1
# Episode 1016  Score -2.0  AVG -2.77
# Episode 1017  Score -2.0  AVG -2.75
# Episode 1018  Score -2.0  AVG -2.76
# Episode 1019  Score -2.0  AVG -2.76
# Episode 1020  Score -2.0  AVG -2.75
# Episode 1021  Score -2.0  AVG -2.75
# Episode 1022  Score -3.0  AVG -2.76
# Episode 1023  Score -9.0  AVG -2.85
# Episode 1024  Score -26.0  AVG -3.11
# Episode 1025  Score -10.0  AVG -3.19
# Episode 1026  Score -1.0  AVG -3.18
# Episode 1027  Score -2.0  AVG -3.18
# Episode 1028  Score -1.0  AVG -3.16
# Episode 1029  Score -2.0  AVG -3.17
# Episode 1030  Score -2.0  AVG -3.1
# Episode 1031  Score -3.0  AVG -3.09
# Episode 1032  Score -3.0  AVG -3.09
# Episode 1033  Score -2.0  AVG -3.11
# Episode 1034  Score -2.0  AVG -3.1
# Episode 1035  Score -3.0  AVG -3.09
# Episode 1036  Score -2.0  AVG -3.09
# Episode 1037  Score -2.0  AVG -3.08
# Episode 1038  Score -5.0  AVG -3.11
# Episode 1039  Score -8.0  AVG -3.16
# Episode 1040  Score -1.0  AVG -3.15
# Episode 1041  Score -1.0  AVG -3.14
# Episode 1042  Score -2.0  AVG -3.14
# Episode 1043  Score -1.0  AVG -3.15
# Episode 1044  Score -3.0  AVG -3.17
# Episode 1045  Score -2.0  AVG -3.18
# Episode 1046  Score -2.0  AVG -3.18
# Episode 1047  Score -1.0  AVG -3.19
# Episode 1048  Score -1.0  AVG -3.17
# Episode 1049  Score -3.0  AVG -3.17
# Episode 1050  Score -2.0  AVG -3.17
# Episode 1051  Score -1.0  AVG -3.17
# Episode 1052  Score -1.0  AVG -3.16
# Episode 1053  Score -3.0  AVG -3.17
# Episode 1054  Score -2.0  AVG -3.19
# Episode 1055  Score 0.0  AVG -3.16
# Episode 1056  Score -2.0  AVG -3.17
# Episode 1057  Score -17.0  AVG -3.32
# Episode 1058  Score -23.0  AVG -3.52
# Episode 1059  Score 0.0  AVG -3.5
# Episode 1060  Score -1.0  AVG -3.49
# Episode 1061  Score -1.0  AVG -3.48
# Episode 1062  Score -2.0  AVG -3.47
# Episode 1063  Score -3.0  AVG -3.48
# Episode 1064  Score -2.0  AVG -3.47
# Episode 1065  Score -1.0  AVG -3.45
# Episode 1066  Score -2.0  AVG -3.44
# Episode 1067  Score -1.0  AVG -3.44
# Episode 1068  Score -3.0  AVG -3.47
# Episode 1069  Score -2.0  AVG -3.48
# Episode 1070  Score -2.0  AVG -3.49
# Episode 1071  Score -2.0  AVG -3.35
# Episode 1072  Score -18.0  AVG -3.4
# Episode 1073  Score -3.0  AVG -3.4
# Episode 1074  Score -2.0  AVG -3.4
# Episode 1075  Score -2.0  AVG -3.4
# Episode 1076  Score -3.0  AVG -3.41
# Episode 1077  Score 0.0  AVG -3.38
# Episode 1078  Score -1.0  AVG -3.36
# Episode 1079  Score -2.0  AVG -3.35
# Episode 1080  Score -1.0  AVG -3.35
# Episode 1081  Score -3.0  AVG -3.36
# Episode 1082  Score -2.0  AVG -3.35
# Episode 1083  Score -2.0  AVG -3.35
# Episode 1084  Score -2.0  AVG -3.36
# Episode 1085  Score -2.0  AVG -3.37
# Episode 1086  Score -2.0  AVG -3.37
# Episode 1087  Score -1.0  AVG -3.35
# Episode 1088  Score -2.0  AVG -3.35
# Episode 1089  Score -1.0  AVG -3.26
# Episode 1090  Score -3.0  AVG -3.26
# Episode 1091  Score -1.0  AVG -3.24
# Episode 1092  Score -24.0  AVG -3.46
# Episode 1093  Score -12.0  AVG -3.57
# Episode 1094  Score -2.0  AVG -3.53
# Episode 1095  Score -6.0  AVG -3.57
# Episode 1096  Score -8.0  AVG -3.63
# Episode 1097  Score -2.0  AVG -3.64
# Episode 1098  Score 0.0  AVG -3.62
# Episode 1099  Score -3.0  AVG -3.64
# Episode 1100  Score -1.0  AVG -3.63
# Episode 1101  Score -3.0  AVG -3.64
# Episode 1102  Score -1.0  AVG -3.65
# Episode 1103  Score 0.0  AVG -3.62
# Episode 1104  Score -2.0  AVG -3.62
# Episode 1105  Score 0.0  AVG -3.61
# Episode 1106  Score -3.0  AVG -3.62
# Episode 1107  Score 0.0  AVG -3.6
# Episode 1108  Score -3.0  AVG -3.62
# Episode 1109  Score -2.0  AVG -3.63
# Episode 1110  Score -1.0  AVG -3.56
# Episode 1111  Score -2.0  AVG -3.54
# Episode 1112  Score -5.0  AVG -3.31
# Episode 1113  Score 0.0  AVG -3.24
# Episode 1114  Score -2.0  AVG -3.24
# Episode 1115  Score -1.0  AVG -3.24
# Episode 1116  Score 0.0  AVG -3.22
# Episode 1117  Score -3.0  AVG -3.23
# Episode 1118  Score 0.0  AVG -3.21
# Episode 1119  Score -2.0  AVG -3.21
# Episode 1120  Score -2.0  AVG -3.21
# Episode 1121  Score 0.0  AVG -3.19
# Episode 1122  Score -2.0  AVG -3.18
# Episode 1123  Score -1.0  AVG -3.1
# Episode 1124  Score -1.0  AVG -2.85
# Episode 1125  Score -2.0  AVG -2.77
# Episode 1126  Score -2.0  AVG -2.78
# Episode 1127  Score 0.0  AVG -2.76
# Episode 1128  Score -3.0  AVG -2.78
# Episode 1129  Score -3.0  AVG -2.79
# Episode 1130  Score -1.0  AVG -2.78
# Episode 1131  Score -1.0  AVG -2.76
# Episode 1132  Score -1.0  AVG -2.74
# Episode 1133  Score -2.0  AVG -2.74
# Episode 1134  Score -2.0  AVG -2.74
# Episode 1135  Score -2.0  AVG -2.73
# Episode 1136  Score -9.0  AVG -2.8
# Episode 1137  Score -5.0  AVG -2.83
# Episode 1138  Score -3.0  AVG -2.81
# Episode 1139  Score -2.0  AVG -2.75
# Episode 1140  Score -2.0  AVG -2.76
# Episode 1141  Score -1.0  AVG -2.76
# Episode 1142  Score -1.0  AVG -2.75
# Episode 1143  Score -2.0  AVG -2.76
# Episode 1144  Score -3.0  AVG -2.76
# Episode 1145  Score -2.0  AVG -2.76
# Episode 1146  Score -2.0  AVG -2.76
# Episode 1147  Score -2.0  AVG -2.77
# Episode 1148  Score -2.0  AVG -2.78
# Episode 1149  Score -20.0  AVG -2.95
# Episode 1150  Score -3.0  AVG -2.96
# Episode 1151  Score -2.0  AVG -2.97
# Episode 1152  Score -3.0  AVG -2.99
# Episode 1153  Score -1.0  AVG -2.97
# Episode 1154  Score -3.0  AVG -2.98
# Episode 1155  Score -2.0  AVG -3.0
# Episode 1156  Score -3.0  AVG -3.01
# Episode 1157  Score 0.0  AVG -2.84
# Episode 1158  Score -1.0  AVG -2.62
# Episode 1159  Score -3.0  AVG -2.65
# Episode 1160  Score -2.0  AVG -2.66
# Episode 1161  Score -3.0  AVG -2.68
# Episode 1162  Score -1.0  AVG -2.67
# Episode 1163  Score -2.0  AVG -2.66
# Episode 1164  Score -1.0  AVG -2.65
# Episode 1165  Score -1.0  AVG -2.65
# Episode 1166  Score -10.0  AVG -2.73
# Episode 1167  Score -2.0  AVG -2.74
# Episode 1168  Score -1.0  AVG -2.72
# Episode 1169  Score -2.0  AVG -2.72
# Episode 1170  Score 0.0  AVG -2.7
# Episode 1171  Score -2.0  AVG -2.7
# Episode 1172  Score -3.0  AVG -2.55
# Episode 1173  Score -2.0  AVG -2.54
# Episode 1174  Score -2.0  AVG -2.54
# Episode 1175  Score -2.0  AVG -2.54
# Episode 1176  Score -3.0  AVG -2.54
# Episode 1177  Score -3.0  AVG -2.57
# Episode 1178  Score -3.0  AVG -2.59
# Episode 1179  Score -3.0  AVG -2.6
# Episode 1180  Score -2.0  AVG -2.61
# Episode 1181  Score -1.0  AVG -2.59
# Episode 1182  Score -2.0  AVG -2.59
# Episode 1183  Score -1.0  AVG -2.58
# Episode 1184  Score -2.0  AVG -2.58
# Episode 1185  Score -27.0  AVG -2.83
# Episode 1186  Score -3.0  AVG -2.84
# Episode 1187  Score -3.0  AVG -2.86
# Episode 1188  Score -2.0  AVG -2.86
# Episode 1189  Score -1.0  AVG -2.86
# Episode 1190  Score 0.0  AVG -2.83
# Episode 1191  Score -3.0  AVG -2.85
# Episode 1192  Score -2.0  AVG -2.63
# Episode 1193  Score -1.0  AVG -2.52
# Episode 1194  Score -2.0  AVG -2.52
# Episode 1195  Score 0.0  AVG -2.46
# Episode 1196  Score 0.0  AVG -2.38
# Episode 1197  Score -2.0  AVG -2.38
# Episode 1198  Score -1.0  AVG -2.39
# Episode 1199  Score -2.0  AVG -2.38
# Episode 1200  Score -3.0  AVG -2.4
# Episode 1201  Score -3.0  AVG -2.4
# Episode 1202  Score -2.0  AVG -2.41
# Episode 1203  Score -2.0  AVG -2.43
# Episode 1204  Score -2.0  AVG -2.43
# Episode 1205  Score 0.0  AVG -2.43
# Episode 1206  Score -3.0  AVG -2.43
# Episode 1207  Score -2.0  AVG -2.45
# Episode 1208  Score -2.0  AVG -2.44
# Episode 1209  Score -2.0  AVG -2.44
# Episode 1210  Score -2.0  AVG -2.45
# Episode 1211  Score -2.0  AVG -2.45
# Episode 1212  Score -1.0  AVG -2.41
# Episode 1213  Score 0.0  AVG -2.41
# Episode 1214  Score -2.0  AVG -2.41
# Episode 1215  Score -1.0  AVG -2.41
# Episode 1216  Score -2.0  AVG -2.43
# Episode 1217  Score -2.0  AVG -2.42
# Episode 1218  Score -2.0  AVG -2.44
# Episode 1219  Score -3.0  AVG -2.45
# Episode 1220  Score -1.0  AVG -2.44
# Episode 1221  Score 0.0  AVG -2.44
# Episode 1222  Score -3.0  AVG -2.45
# Episode 1223  Score 0.0  AVG -2.44
# Episode 1224  Score -3.0  AVG -2.46
# Episode 1225  Score 0.0  AVG -2.44
# Episode 1226  Score 0.0  AVG -2.42
# Episode 1227  Score -2.0  AVG -2.44
# Episode 1228  Score -3.0  AVG -2.44
# Episode 1229  Score 0.0  AVG -2.41
# Episode 1230  Score -2.0  AVG -2.42
# Episode 1231  Score -1.0  AVG -2.42
# Episode 1232  Score -11.0  AVG -2.52
# Episode 1233  Score -7.0  AVG -2.57
# Episode 1234  Score -3.0  AVG -2.58
# Episode 1235  Score -1.0  AVG -2.57
# Episode 1236  Score -2.0  AVG -2.5
# Episode 1237  Score -6.0  AVG -2.51
# Episode 1238  Score 0.0  AVG -2.48
# Episode 1239  Score -2.0  AVG -2.48
# Episode 1240  Score -2.0  AVG -2.48
# Episode 1241  Score -3.0  AVG -2.5
# Episode 1242  Score 0.0  AVG -2.49
# Episode 1243  Score -2.0  AVG -2.49
# Episode 1244  Score -2.0  AVG -2.48
# Episode 1245  Score -3.0  AVG -2.49
# Episode 1246  Score 0.0  AVG -2.47
# Episode 1247  Score 0.0  AVG -2.45
# Episode 1248  Score -2.0  AVG -2.45
# Episode 1249  Score -2.0  AVG -2.27
# Episode 1250  Score -1.0  AVG -2.25
# Episode 1251  Score -2.0  AVG -2.25
# Episode 1252  Score -3.0  AVG -2.25
# Episode 1253  Score 0.0  AVG -2.24
# Episode 1254  Score -2.0  AVG -2.23
# Episode 1255  Score -3.0  AVG -2.24
# Episode 1256  Score -2.0  AVG -2.23
# Episode 1257  Score -1.0  AVG -2.24
# Episode 1258  Score -2.0  AVG -2.25
# Episode 1259  Score -2.0  AVG -2.24
# Episode 1260  Score -1.0  AVG -2.23
# Episode 1261  Score -2.0  AVG -2.22
# Episode 1262  Score -2.0  AVG -2.23
# Episode 1263  Score -4.0  AVG -2.25
# Episode 1264  Score -2.0  AVG -2.26
# Episode 1265  Score -1.0  AVG -2.26
# Episode 1266  Score -2.0  AVG -2.18
# Episode 1267  Score -3.0  AVG -2.19
# Episode 1268  Score -2.0  AVG -2.2
# Episode 1269  Score -9.0  AVG -2.27
# Episode 1270  Score -3.0  AVG -2.3
# Episode 1271  Score -3.0  AVG -2.31
# Episode 1272  Score -2.0  AVG -2.3
# Episode 1273  Score -3.0  AVG -2.31
# Episode 1274  Score -2.0  AVG -2.31
# Episode 1275  Score -1.0  AVG -2.3
# Episode 1276  Score -1.0  AVG -2.28
# Episode 1277  Score -3.0  AVG -2.28
# Episode 1278  Score -1.0  AVG -2.26
# Episode 1279  Score -3.0  AVG -2.26
# Episode 1280  Score -3.0  AVG -2.27
# Episode 1281  Score 0.0  AVG -2.26
# Episode 1282  Score -2.0  AVG -2.26
# Episode 1283  Score -1.0  AVG -2.26
# Episode 1284  Score -2.0  AVG -2.26
# Episode 1285  Score -2.0  AVG -2.01
# Episode 1286  Score -3.0  AVG -2.01
# Episode 1287  Score 0.0  AVG -1.98
# Episode 1288  Score -3.0  AVG -1.99
# Episode 1289  Score -3.0  AVG -2.01
# Episode 1290  Score -2.0  AVG -2.03
# Episode 1291  Score -1.0  AVG -2.01
# Episode 1292  Score -3.0  AVG -2.02
# Episode 1293  Score -2.0  AVG -2.03
# Episode 1294  Score 0.0  AVG -2.01
# Episode 1295  Score -2.0  AVG -2.03
# Episode 1296  Score -3.0  AVG -2.06
# Episode 1297  Score -2.0  AVG -2.06
# Episode 1298  Score -1.0  AVG -2.06
# Episode 1299  Score -5.0  AVG -2.09
# Episode 1300  Score -3.0  AVG -2.09
# Episode 1301  Score -2.0  AVG -2.08
# Episode 1302  Score -2.0  AVG -2.08
# Episode 1303  Score -2.0  AVG -2.08
# Episode 1304  Score -2.0  AVG -2.08
# Episode 1305  Score -2.0  AVG -2.1
# Episode 1306  Score -1.0  AVG -2.08
# Episode 1307  Score -1.0  AVG -2.07
# Episode 1308  Score -2.0  AVG -2.07
# Episode 1309  Score -2.0  AVG -2.07
# Episode 1310  Score 0.0  AVG -2.05
# Episode 1311  Score -3.0  AVG -2.06
# Episode 1312  Score -16.0  AVG -2.21
# Episode 1313  Score -3.0  AVG -2.24
# Episode 1314  Score -2.0  AVG -2.24
# Episode 1315  Score -3.0  AVG -2.26
# Episode 1316  Score -49.0  AVG -2.73
# Episode 1317  Score -2.0  AVG -2.73
# Episode 1318  Score -15.0  AVG -2.86
# Episode 1319  Score -2.0  AVG -2.85
# Episode 1320  Score -40.0  AVG -3.24
# Episode 1321  Score -5.0  AVG -3.29
# Episode 1322  Score -1.0  AVG -3.27
# Episode 1323  Score -2.0  AVG -3.29
# Episode 1324  Score -1.0  AVG -3.27
# Episode 1325  Score -2.0  AVG -3.29
# Episode 1326  Score -2.0  AVG -3.31
# Episode 1327  Score -1.0  AVG -3.3
# Episode 1328  Score -1.0  AVG -3.28
# Episode 1329  Score -1.0  AVG -3.29
# Episode 1330  Score -2.0  AVG -3.29
# Episode 1331  Score -2.0  AVG -3.3
# Episode 1332  Score -3.0  AVG -3.22
# Episode 1333  Score 0.0  AVG -3.15
# Episode 1334  Score -1.0  AVG -3.13
# Episode 1335  Score 0.0  AVG -3.12
# Episode 1336  Score -3.0  AVG -3.13
# Episode 1337  Score -1.0  AVG -3.08
# Episode 1338  Score -2.0  AVG -3.1
# Episode 1339  Score -2.0  AVG -3.1
# Episode 1340  Score -2.0  AVG -3.1
# Episode 1341  Score -1.0  AVG -3.08
# Episode 1342  Score -1.0  AVG -3.09
# Episode 1343  Score -17.0  AVG -3.24
# Episode 1344  Score -2.0  AVG -3.24
# Episode 1345  Score -2.0  AVG -3.23
# Episode 1346  Score -2.0  AVG -3.25
# Episode 1347  Score -1.0  AVG -3.26
# Episode 1348  Score -2.0  AVG -3.26
# Episode 1349  Score -3.0  AVG -3.27
# Episode 1350  Score -10.0  AVG -3.36
# Episode 1351  Score -16.0  AVG -3.5
# Episode 1352  Score -13.0  AVG -3.6
# Episode 1353  Score -1.0  AVG -3.61
# Episode 1354  Score -2.0  AVG -3.61
# Episode 1355  Score -1.0  AVG -3.59
# Episode 1356  Score -3.0  AVG -3.6
# Episode 1357  Score 0.0  AVG -3.59
# Episode 1358  Score 0.0  AVG -3.57
# Episode 1359  Score -3.0  AVG -3.58
# Episode 1360  Score -3.0  AVG -3.6
# Episode 1361  Score -2.0  AVG -3.6
# Episode 1362  Score -2.0  AVG -3.6
# Episode 1363  Score -2.0  AVG -3.58
# Episode 1364  Score 0.0  AVG -3.56
# Episode 1365  Score -3.0  AVG -3.58
# Episode 1366  Score -3.0  AVG -3.59
# Episode 1367  Score -3.0  AVG -3.59
# Episode 1368  Score -3.0  AVG -3.6
# Episode 1369  Score -17.0  AVG -3.68
# Episode 1370  Score -30.0  AVG -3.95
# Episode 1371  Score -8.0  AVG -4.0
# Episode 1372  Score -2.0  AVG -4.0
# Episode 1373  Score -2.0  AVG -3.99
# Episode 1374  Score -3.0  AVG -4.0
# Episode 1375  Score -2.0  AVG -4.01
# Episode 1376  Score -17.0  AVG -4.17
# Episode 1377  Score -3.0  AVG -4.17
# Episode 1378  Score -6.0  AVG -4.22
# Episode 1379  Score -1.0  AVG -4.2
# Episode 1380  Score -2.0  AVG -4.19
# Episode 1381  Score -3.0  AVG -4.22
# Episode 1382  Score 0.0  AVG -4.2
# Episode 1383  Score -2.0  AVG -4.21
# Episode 1384  Score -3.0  AVG -4.22
# Episode 1385  Score -3.0  AVG -4.23
# Episode 1386  Score -3.0  AVG -4.23
# Episode 1387  Score -3.0  AVG -4.26
# Episode 1388  Score -2.0  AVG -4.25
# Episode 1389  Score -2.0  AVG -4.24
# Episode 1390  Score 0.0  AVG -4.22
# Episode 1391  Score -1.0  AVG -4.22
# Episode 1392  Score -1.0  AVG -4.2
# Episode 1393  Score -1.0  AVG -4.19
# Episode 1394  Score -1.0  AVG -4.2
# Episode 1395  Score -2.0  AVG -4.2
# Episode 1396  Score -2.0  AVG -4.19
# Episode 1397  Score 0.0  AVG -4.17
# Episode 1398  Score -2.0  AVG -4.18
# Episode 1399  Score -2.0  AVG -4.15
# Episode 1400  Score -1.0  AVG -4.13
# Episode 1401  Score -2.0  AVG -4.13
# Episode 1402  Score -1.0  AVG -4.12
# Episode 1403  Score -2.0  AVG -4.12
# Episode 1404  Score -2.0  AVG -4.12
# Episode 1405  Score -2.0  AVG -4.12
# Episode 1406  Score 0.0  AVG -4.11
# Episode 1407  Score 0.0  AVG -4.1
# Episode 1408  Score 0.0  AVG -4.08
# Episode 1409  Score -19.0  AVG -4.25
# Episode 1410  Score 0.0  AVG -4.25
# Episode 1411  Score -3.0  AVG -4.25
# Episode 1412  Score -1.0  AVG -4.1
# Episode 1413  Score -2.0  AVG -4.09
# Episode 1414  Score -3.0  AVG -4.1
# Episode 1415  Score -1.0  AVG -4.08
# Episode 1416  Score -1.0  AVG -3.6
# Episode 1417  Score -2.0  AVG -3.6
# Episode 1418  Score -1.0  AVG -3.46
# Episode 1419  Score -1.0  AVG -3.45
# Episode 1420  Score -2.0  AVG -3.07
# Episode 1421  Score -2.0  AVG -3.04
# Episode 1422  Score -2.0  AVG -3.05
# Episode 1423  Score -2.0  AVG -3.05
# Episode 1424  Score -1.0  AVG -3.05
# Episode 1425  Score -9.0  AVG -3.12
# Episode 1426  Score -3.0  AVG -3.13

# %%
plt.plot(avg_scores)
plt.grid()
plt.xlabel('Episodes')
plt.ylabel('Avg rewards')

# %%
env = gym.make('FetchReach-v1')

for i in range(10):
    dic = env.reset()
    state, desired_goal = dic['observation'], dic['desired_goal']
    done = False
    
    while not done:
        action = agent.act(state, desired_goal, True)
        dic, _, done, _ = env.step(action)
        n_state = dic['observation']
        state = n_state
        env.render()
env.close()

# %%
agent.actor_main.save_weights('actor_weights.h5')
