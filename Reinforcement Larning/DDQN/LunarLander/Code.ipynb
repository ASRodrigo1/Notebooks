# %%
import warnings
warnings.simplefilter('ignore')
import tensorflow as tf
print("Is GPU available?", tf.test.is_gpu_available())
print("TF version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
# Out:
# Is GPU available? True
# TF version: 1.15.4
# Keras version: 2.2.4-tf

# %%
import gym
import numpy as np
import random
import matplotlib.pyplot as plt
from collections import deque
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %%
class Agent():
    def __init__(self, input_shape, n_actions, mem_size, eps, eps_min, eps_dec, gamma, q_eval_name, q_next_name, 
                 replace_freq, lr=0.0001):
        self.Q_eval = self._build_NN(input_shape, n_actions, lr)
        self.Q_next = self._build_NN(input_shape, n_actions, lr)
        #self.Q_eval = load_model('Q_eval.h5')
        #self.Q_next = load_model('Q_next.h5')
        self.memory = deque(maxlen=mem_size)
        self.eps = eps
        self.eps_min = eps_min
        self.eps_dec = eps_dec
        self.gamma = gamma
        self.replace = replace_freq
        self.action_space = [i for i in range(n_actions)]
        self.steps = 0
        self.input_shape = input_shape
        self.q_eval_name = q_eval_name
        self.q_next_name = q_next_name
    
    def _build_NN(self, input_shape, n_actions, lr):
        
        model = Sequential()
        
        model.add(Dense(64, input_shape=(*input_shape,), activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(n_actions, activation='linear'))
        
        model.compile(optimizer=Adam(lr=lr), loss='mse')
        
        model.summary()
        
        return model
    
    def store(self, state, action, reward, n_state, done):
        pack = [np.expand_dims(state, axis=0), action, reward, np.expand_dims(n_state, axis=0), done]
        self.memory.append(pack)
    
    def take_data(self, batch_size):
        pack = random.sample(self.memory, batch_size)
        states = []
        actions = []
        rewards = []
        n_states = []
        dones = []
        for i in range(batch_size):
            states.append(pack[i][0])
            actions.append(pack[i][1])
            rewards.append(pack[i][2])
            n_states.append(pack[i][3])
            dones.append(pack[i][4])
        return states, actions, rewards, n_states, dones
    
    def choose_action(self, state):
        if np.random.random() > self.eps:
            return np.argmax(self.Q_eval.predict(state))
        else:
            return np.random.choice(self.action_space)
    
    def decay_eps(self): 
        self.eps = self.eps - self.eps_dec if self.eps > self.eps_min else self.eps_min
    
    def replace_weights(self):
        if not (self.steps % self.replace):
            self.Q_next.set_weights(self.Q_eval.get_weights())
    
    def upgrade(self, batch_size=32):
        if len(self.memory) >= 4*batch_size:
            states, actions, rewards, n_states, dones = self.take_data(batch_size)
            
            self.replace_weights()
            
            ### DDQN
            act = [np.argmax(self.Q_eval.predict(n_states[i])) for i in range(batch_size)]
            
            q_next = [self.Q_next.predict(n_states[i])[0][act[i]] for i in range(batch_size)]
            
            y = [self.Q_eval.predict(states[i])[0] for i in range(batch_size)]
            
            for i in range(batch_size):
                y[i][actions[i]] = rewards[i] + self.gamma*q_next[i]*(1 - dones[i])
            ###
            
            states = np.reshape(states, (batch_size, *self.input_shape))
            
            self.Q_eval.fit(np.array(states), np.array(y), epochs=1, verbose=0, batch_size=batch_size)
            
            self.decay_eps()
            self.steps += 1

    def save(self):
        self.Q_eval.save(self.q_eval_name)
        self.Q_next.save(self.q_next_name)

# %%
env = gym.make("LunarLander-v2")
n_games = 500
agent = Agent(input_shape=env.observation_space.shape, n_actions=env.action_space.n, mem_size=10000, eps=1.0, 
              eps_min=0.001, eps_dec=0.001, gamma=0.95, q_eval_name='Q_eval.h5', q_next_name='Q_next.h5', 
              replace_freq=1000)
best_score = -200
scores = []
means = []
eps = []
for i in range(n_games):
    done = False
    state = env.reset()
    score = 0
    while not done:
        action = agent.choose_action(np.expand_dims(state, axis=0))
        n_state, reward, done, _ = env.step(action)
        if done:
            reward -= 150
        score += reward
        agent.store(state, action, reward, n_state, int(done))
        agent.upgrade()
        state = n_state
    scores.append(score)
    mean = np.mean(scores[-20:])
    means.append(mean)
    eps.append(agent.eps)
    if mean > best_score:
        agent.save()
        best_score = mean
    if np.mean(scores[-100:]) >= 220:
        print("Environment Solved!")
        agent.save()
        break
    print('episode: ', i+1, '   score: ', int(score), '   eps:  %.3f' %agent.eps)
env.close()
# Out:
# WARNING:tensorflow:From C:\Users\Rodrigo\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                576
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 4,996
# Trainable params: 4,996
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 64)                576
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 4,996
# Trainable params: 4,996
# Non-trainable params: 0
# _________________________________________________________________
# episode:  1    score:  -453    eps:  1.000
# episode:  2    score:  -308    eps:  0.941
# episode:  3    score:  -252    eps:  0.869
# episode:  4    score:  -275    eps:  0.799
# episode:  5    score:  -550    eps:  0.686
# episode:  6    score:  -663    eps:  0.497
# episode:  7    score:  -491    eps:  0.416
# episode:  8    score:  -291    eps:  0.314
# episode:  9    score:  -311    eps:  0.202
# episode:  10    score:  -550    eps:  0.016
# episode:  11    score:  -484    eps:  0.001
# episode:  12    score:  -516    eps:  0.001
# episode:  13    score:  -348    eps:  0.001
# episode:  14    score:  -187    eps:  0.001
# episode:  15    score:  -170    eps:  0.001
# episode:  16    score:  -356    eps:  0.001
# episode:  17    score:  -379    eps:  0.001
# episode:  18    score:  -346    eps:  0.001
# episode:  19    score:  -227    eps:  0.001
# episode:  20    score:  -330    eps:  0.001
# episode:  21    score:  -284    eps:  0.001
# episode:  22    score:  -305    eps:  0.001
# episode:  23    score:  -335    eps:  0.001
# episode:  24    score:  -388    eps:  0.001
# episode:  25    score:  -354    eps:  0.001
# episode:  26    score:  -326    eps:  0.001
# episode:  27    score:  -329    eps:  0.001
# episode:  28    score:  -402    eps:  0.001
# episode:  29    score:  -377    eps:  0.001
# episode:  30    score:  -459    eps:  0.001
# episode:  31    score:  -360    eps:  0.001
# episode:  32    score:  -515    eps:  0.001
# episode:  33    score:  -302    eps:  0.001
# episode:  34    score:  -328    eps:  0.001
# episode:  35    score:  -338    eps:  0.001
# episode:  36    score:  -315    eps:  0.001
# episode:  37    score:  -303    eps:  0.001
# episode:  38    score:  -343    eps:  0.001
# episode:  39    score:  -365    eps:  0.001
# episode:  40    score:  -624    eps:  0.001
# episode:  41    score:  -365    eps:  0.001
# episode:  42    score:  -837    eps:  0.001
# episode:  43    score:  -473    eps:  0.001
# episode:  44    score:  -487    eps:  0.001
# episode:  45    score:  -319    eps:  0.001
# episode:  46    score:  -407    eps:  0.001
# episode:  47    score:  -359    eps:  0.001
# episode:  48    score:  -347    eps:  0.001
# episode:  49    score:  -335    eps:  0.001
# episode:  50    score:  -289    eps:  0.001
# episode:  51    score:  -574    eps:  0.001
# episode:  52    score:  -324    eps:  0.001
# episode:  53    score:  -417    eps:  0.001
# episode:  54    score:  -280    eps:  0.001
# episode:  55    score:  -445    eps:  0.001
# episode:  56    score:  -547    eps:  0.001
# episode:  57    score:  -447    eps:  0.001
# episode:  58    score:  -705    eps:  0.001
# episode:  59    score:  -395    eps:  0.001
# episode:  60    score:  -315    eps:  0.001
# episode:  61    score:  -428    eps:  0.001
# episode:  62    score:  -475    eps:  0.001
# episode:  63    score:  -415    eps:  0.001
# episode:  64    score:  -416    eps:  0.001
# episode:  65    score:  -551    eps:  0.001
# episode:  66    score:  -523    eps:  0.001
# episode:  67    score:  -546    eps:  0.001
# episode:  68    score:  -635    eps:  0.001
# episode:  69    score:  -470    eps:  0.001
# episode:  70    score:  -406    eps:  0.001
# episode:  71    score:  -189    eps:  0.001
# episode:  72    score:  -390    eps:  0.001
# episode:  73    score:  -131    eps:  0.001
# episode:  74    score:  -202    eps:  0.001
# episode:  75    score:  -360    eps:  0.001
# episode:  76    score:  -300    eps:  0.001
# episode:  77    score:  -206    eps:  0.001
# episode:  78    score:  -230    eps:  0.001
# episode:  79    score:  -623    eps:  0.001
# episode:  80    score:  -184    eps:  0.001
# episode:  81    score:  -380    eps:  0.001
# episode:  82    score:  -171    eps:  0.001
# episode:  83    score:  -192    eps:  0.001
# episode:  84    score:  -385    eps:  0.001
# episode:  85    score:  -359    eps:  0.001
# episode:  86    score:  -173    eps:  0.001
# episode:  87    score:  -372    eps:  0.001
# episode:  88    score:  -288    eps:  0.001
# episode:  89    score:  -249    eps:  0.001
# episode:  90    score:  -362    eps:  0.001
# episode:  91    score:  -228    eps:  0.001
# episode:  92    score:  -271    eps:  0.001
# episode:  93    score:  -347    eps:  0.001
# episode:  94    score:  -430    eps:  0.001
# episode:  95    score:  -391    eps:  0.001
# episode:  96    score:  -340    eps:  0.001
# episode:  97    score:  -244    eps:  0.001
# episode:  98    score:  -187    eps:  0.001
# episode:  99    score:  -374    eps:  0.001
# episode:  100    score:  -229    eps:  0.001
# episode:  101    score:  -383    eps:  0.001
# episode:  102    score:  -423    eps:  0.001
# episode:  103    score:  -183    eps:  0.001
# episode:  104    score:  -150    eps:  0.001
# episode:  105    score:  -203    eps:  0.001
# episode:  106    score:  -260    eps:  0.001
# episode:  107    score:  -353    eps:  0.001
# episode:  108    score:  -200    eps:  0.001
# episode:  109    score:  -340    eps:  0.001
# episode:  110    score:  -247    eps:  0.001
# episode:  111    score:  -461    eps:  0.001
# episode:  112    score:  -349    eps:  0.001
# episode:  113    score:  -284    eps:  0.001
# episode:  114    score:  -434    eps:  0.001
# episode:  115    score:  -265    eps:  0.001
# episode:  116    score:  -291    eps:  0.001
# episode:  117    score:  -430    eps:  0.001
# episode:  118    score:  -364    eps:  0.001
# episode:  119    score:  -322    eps:  0.001
# episode:  120    score:  -438    eps:  0.001
# episode:  121    score:  -236    eps:  0.001
# episode:  122    score:  -230    eps:  0.001
# episode:  123    score:  -224    eps:  0.001
# episode:  124    score:  -406    eps:  0.001
# episode:  125    score:  -189    eps:  0.001
# episode:  126    score:  -177    eps:  0.001
# episode:  127    score:  -277    eps:  0.001
# episode:  128    score:  -447    eps:  0.001
# episode:  129    score:  -423    eps:  0.001
# episode:  130    score:  -395    eps:  0.001
# episode:  131    score:  -216    eps:  0.001
# episode:  132    score:  -311    eps:  0.001
# episode:  133    score:  -157    eps:  0.001
# episode:  134    score:  -280    eps:  0.001
# episode:  135    score:  -250    eps:  0.001
# episode:  136    score:  -208    eps:  0.001
# episode:  137    score:  -176    eps:  0.001
# episode:  138    score:  -249    eps:  0.001
# episode:  139    score:  -209    eps:  0.001
# episode:  140    score:  -135    eps:  0.001
# episode:  141    score:  -241    eps:  0.001
# episode:  142    score:  -201    eps:  0.001
# episode:  143    score:  -139    eps:  0.001
# episode:  144    score:  -300    eps:  0.001
# episode:  145    score:  -284    eps:  0.001
# episode:  146    score:  -249    eps:  0.001
# episode:  147    score:  -147    eps:  0.001
# episode:  148    score:  -258    eps:  0.001
# episode:  149    score:  -301    eps:  0.001
# episode:  150    score:  -198    eps:  0.001
# episode:  151    score:  -124    eps:  0.001
# episode:  152    score:  -413    eps:  0.001
# episode:  153    score:  -365    eps:  0.001
# episode:  154    score:  -379    eps:  0.001
# episode:  155    score:  -353    eps:  0.001
# episode:  156    score:  -328    eps:  0.001
# episode:  157    score:  -159    eps:  0.001
# episode:  158    score:  -239    eps:  0.001
# episode:  159    score:  -265    eps:  0.001
# episode:  160    score:  -225    eps:  0.001
# episode:  161    score:  -292    eps:  0.001
# episode:  162    score:  -132    eps:  0.001
# episode:  163    score:  -292    eps:  0.001
# episode:  164    score:  -131    eps:  0.001
# episode:  165    score:  -253    eps:  0.001
# episode:  166    score:  -290    eps:  0.001
# episode:  167    score:  -280    eps:  0.001
# episode:  168    score:  -261    eps:  0.001
# episode:  169    score:  -107    eps:  0.001
# episode:  170    score:  -171    eps:  0.001
# episode:  171    score:  -209    eps:  0.001
# episode:  172    score:  -226    eps:  0.001
# episode:  173    score:  -288    eps:  0.001
# episode:  174    score:  -269    eps:  0.001
# episode:  175    score:  -221    eps:  0.001
# episode:  176    score:  -268    eps:  0.001
# episode:  177    score:  -244    eps:  0.001
# episode:  178    score:  -360    eps:  0.001
# episode:  179    score:  -299    eps:  0.001
# episode:  180    score:  -250    eps:  0.001
# episode:  181    score:  -320    eps:  0.001
# episode:  182    score:  -373    eps:  0.001
# episode:  183    score:  -335    eps:  0.001
# episode:  184    score:  -149    eps:  0.001
# episode:  185    score:  -123    eps:  0.001
# episode:  186    score:  -196    eps:  0.001

# %%
plt.plot(scores)
plt.grid()
plt.show()

# %%
plt.plot(means)
plt.grid()
plt.show()

# %%
plt.plot(eps)
plt.grid()
plt.show()

# %%
Q = load_model('Q_eval.h5')
env = gym.make("LunarLander-v2")
for i in range(20):
    done = False
    state = env.reset()
    while not done:
        env.render()
        action = np.argmax(Q.predict(np.expand_dims(state, axis=0))[0])
        n_state, reward, done, _ = env.step(action)
        state = n_state
env.close()
